# %%
import nltk
nltk.download()

from nltk.stem.snowball import SnowballStemmer
stemmer=SnowballStemmer("dutch")

from nltk.corpus import stopwords
stopwords_ned = stopwords.words('dutch')
stopwords_eng = stopwords.words('english')
stopwords = stopwords_eng + stopwords_ned

import re

moraldic = open("/home/linda/manifestos/manifestos/mf/dutch moral foundations dictionary ext.1.dic").read().replace("\t", "").replace("\s", "")


harmvirtue_ned = re.findall('([a-z]+\*?).*[0][1]', moraldic)
harmvice_ned = re.findall('([a-z]+\*?).*[0][2]', moraldic)
fairnessvirtue_ned = re.findall('([a-z]+\*?).*[0][3]', moraldic)
fairnessvice_ned = re.findall('([a-z]+\*?).*[0][4]', moraldic)
ingroupvirtue_ned = re.findall('([a-z]+\*?).*[0][5]', moraldic)
ingroupvice_ned = re.findall('([a-z]+\*?).*[0][6]', moraldic)
authorityvirtue_ned = re.findall('([a-z]+\*?).*[0][7]', moraldic)
authorityvice_ned = re.findall('([a-z]+\*?).*[0][8]', moraldic)
purityvirtue_ned = re.findall('([a-z]+\*?).*[0][9]', moraldic)
purityvice_ned = re.findall('([a-z]+\*?).*[1][0]', moraldic)
moralitygeneral_ned = re.findall('([a-z]+\*?).*[1][1]', moraldic)
libertyvirtue_ned = re.findall('([a-z]+\*?).*[1][2]', moraldic)
libertyvice_ned = re.findall('([a-z]+\*?).*[1][3]', moraldic)


moralityall_ned = re.findall('([a-z]+\*?).*[01-11]', moraldic)
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml

# %%
print(purityvice_ned)
# Out:
# ['verwoest*', 'uitbuit*', 'schend*', 'afvallig*', 'ontaard', 'ketter*', 'ontkerkelijk*', 'afschuwelijk*', 'afkeer', 'bederven', 'bedorven', 'rot', 'bederf*', 'vuil*', 'bevlekt*', 'onkuiz*', 'onrein*', 'onfatsoen*', 'zonde*', 'zondig', 'zondaar', 'zondaren', 'slet*', 'hoer*', 'goddelo*', 'onkerkelijk', 'ontheilig*', 'vulgair*', 'plat', 'afstotend*', 'weerzinwekkend*', 'walg*', 'promiscue', 'obsceen', 'obscen*', 'schunnig*', 'overspel*', 'verdorven', 'lichtzinnig*', 'liederlijk*', 'bevuil*', 'zwerver', 'prostitut*', 'onkuis', 'buitensporig*', 'losbol', 'losbandig*', 'viezigheid', 'ordinair*', 'laks*', 'nalatig*', 'smet', 'besmet*', 'vlek', 'bezoedel*', 'verneder*', 'kwaadaardig*', 'kwalijk*', 'pervers*', 'viezerik', 'verachtelijk', 'vervuilen*', 'tuig', 'onbeschaafde', 'onbeschoft*', 'laaghartig*']

# %%
moraldic_eng = open("/home/linda/manifestos/manifestos/mf/moral foundations dictionary ext.1.dic").read().replace("\t", "").replace("\s", "")


harmvirtue_eng = re.findall('([a-z]+\*?).*[0][1]', moraldic_eng)
harmvice_eng = re.findall('([a-z]+\*?).*[0][2]', moraldic_eng)
fairnessvirtue_eng = re.findall('([a-z]+\*?).*[0][3]', moraldic_eng)
fairnessvice_eng = re.findall('([a-z]+\*?).*[0][4]', moraldic_eng)
ingroupvirtue_eng = re.findall('([a-z]+\*?).*[0][5]', moraldic)
ingroupvice_eng = re.findall('([a-z]+\*?).*[0][6]', moraldic_eng)
authorityvirtue_eng = re.findall('([a-z]+\*?).*[0][7]', moraldic_eng)
authorityvice_eng = re.findall('([a-z]+\*?).*[0][8]', moraldic_eng)
purityvirtue_eng = re.findall('([a-z]+\*?).*[0][9]', moraldic_eng)
purityvice_eng = re.findall('([a-z]+\*?).*[1][0]', moraldic_eng)
moralitygeneral_eng = re.findall('([a-z]+\*?).*[1][1]', moraldic_eng)
libertyvirtue_eng = re.findall('([a-z]+\*?).*[1][2]', moraldic_eng)
libertyvice_eng = re.findall('([a-z]+\*?).*[1][3]', moraldic_eng)


moralityall_eng = re.findall('([a-z]+\*?).*[01-11]', moraldic_eng)

# %%
print(libertyvice_eng)
# Out:
# ['oppress*', 'limit*', 'force*', 'dependen*', 'interfer*', 'obstruct', 'hinder*', 'infringe*', 'breach*', 'violat*']

# %%
harmvirtue = harmvirtue_eng + harmvirtue_ned
harmvice = harmvice_eng + harmvice_ned
fairnessvirtue = fairnessvirtue_eng + fairnessvirtue_ned
fairnessvice = fairnessvice_eng + fairnessvice_ned
ingroupvirtue = ingroupvirtue_eng + ingroupvirtue_ned
ingroupvice = ingroupvice_eng + ingroupvice_ned
authorityvirtue = authorityvirtue_eng + authorityvirtue_ned
authorityvice = authorityvice_eng + authorityvice_ned
purityvirtue = purityvirtue_eng + purityvirtue_ned
purityvice = purityvice_eng + purityvice_ned
libertyvirtue = libertyvirtue_eng + libertyvirtue_ned
libertyvice = libertyvice_eng + libertyvice_ned
moralitygeneral = moralitygeneral_eng + moralitygeneral_ned
moralityall = moralityall_eng + moralityall_ned

# %%
import csv
from glob import glob
import re
from itertools import islice
import string

names=[]
parties=[]
lidmaatschap = {}


alltweets = glob("/home/linda/manifestos/tweets/downloads/NL 2018/tweets/*.csv")
peeps = [p.split('/')[-1].strip('.csv.') for p in alltweets]

names = [pp.split('_')[-3].strip() for pp in peeps]
parties = [pp.split('_')[-2].strip() for pp in peeps]

lidmaatschap = dict(zip(names,parties))
filenames = dict(zip(names, alltweets))


for name in names:
    ids=[]
    favourites=[]
    retweets=[]
    dates=[]
    quote=[]
    rt=[]
    text=[]
    file = filenames[name]
    print("now opening", file)
    with open(file) as fi:
        reader = csv.reader(fi,delimiter=',')
        for row in csv.reader(islice(fi, None)):
            ids.append(row[0])
            favourites.append(row[1])
            retweets.append(row[2])
            dates.append(row[3])
            quote.append(row[4])
            rt.append(row[5])
            text.append(row[6]) 
        translate_table = dict((ord(char), None) for char in string.punctuation)   
        text = [t.translate(translate_table) for t in text]
        text = [t.lower() for t in text]
        text = [t.strip() for t in text if t.strip()!=""]
        text = [t.strip() for t in text if len(t)> 10]
        text = [' '.join(w for w in t.split() if w.lower() not in stopwords) for t in text]
        morallist=[]
        harmvirtuelist = []
        harmvicelist = []
        fairnessvirtuelist = []
        fairnessvicelist = []
        ingroupvirtuelist = []
        ingroupvicelist = []
        authorityvirtuelist = []
        authorityvicelist = []
        purityvirtuelist = []
        purityvicelist = []
        moralgenlist = []
        libertyvirtuelist = []
        libertyvicelist = []
        harmlist = []
        fairnesslist = []
        ingrouplist = []
        authoritylist = []
        puritylist = []
        libertylist=[]
        length=[]
        for line in text:
            moralcount=0
            harmvirtuecount=0
            harmvicecount=0
            fairnessvirtuecount=0
            fairnessvicecount=0
            ingroupvirtuecount=0
            ingroupvicecount=0
            authorityvirtuecount=0
            authorityvicecount=0
            purityvirtuecount=0
            purityvicecount=0
            libertyvirtuecount=0
            libertyvicecount=0
            moralgencount=0
            for pattern in moralityall:
                for word in line.split():
                    if pattern[-1] == '*' and word.startswith(pattern[:-1]) or word == pattern:
                        moralcount+=1
            for pattern in harmvirtue:
                for word in line.split():
                    if pattern[-1] == '*' and word.startswith(pattern[:-1]) or word == pattern:
                        harmvirtuecount+=1
            for pattern in harmvice:
                for word in line.split():
                    if pattern[-1] == '*' and word.startswith(pattern[:-1]) or word == pattern:
                        harmvicecount+=1
            for pattern in fairnessvirtue:
                for word in line.split():
                    if pattern[-1] == '*' and word.startswith(pattern[:-1]) or word == pattern:
                        fairnessvirtuecount+=1
            for pattern in fairnessvice:
                for word in line.split():
                    if pattern[-1] == '*' and word.startswith(pattern[:-1]) or word == pattern:
                        fairnessvicecount+=1
            for pattern in ingroupvirtue:
                for word in line.split():
                    if pattern[-1] == '*' and word.startswith(pattern[:-1]) or word == pattern:
                        ingroupvirtuecount+=1
            for pattern in ingroupvice:
                for word in line.split():
                    if pattern[-1] == '*' and word.startswith(pattern[:-1]) or word == pattern:
                        ingroupvicecount+=1
            for pattern in authorityvirtue:
                for word in line.split():
                    if pattern[-1] == '*' and word.startswith(pattern[:-1]) or word == pattern:
                        authorityvirtuecount+=1
            for pattern in authorityvice:
                for word in line.split():
                    if pattern[-1] == '*' and word.startswith(pattern[:-1]) or word == pattern:
                        authorityvicecount+=1
            for pattern in purityvirtue:
                for word in line.split():
                    if pattern[-1] == '*' and word.startswith(pattern[:-1]) or word == pattern:
                        purityvirtuecount+=1
            for pattern in purityvice:
                for word in line.split():
                    if pattern[-1] == '*' and word.startswith(pattern[:-1]) or word == pattern:
                        purityvicecount+=1        
            for pattern in libertyvirtue:
                for word in line.split():
                    if pattern[-1] == '*' and word.startswith(pattern[:-1]) or word == pattern:
                        libertyvirtuecount+=1
            for pattern in libertyvice:
                for word in line.split():
                    if pattern[-1] == '*' and word.startswith(pattern[:-1]) or word == pattern:
                        libertyvicecount+=1
            for pattern in moralitygeneral:
                for word in line.split():
                    if pattern[-1] == '*' and word.startswith(pattern[:-1]) or word == pattern:
                        moralgencount+=1
            morallist.append(moralcount)
            harmvirtuelist.append(harmvirtuecount)
            harmvicelist.append(harmvicecount)
            harmlist.append(harmvicecount+harmvirtuecount)
            fairnessvirtuelist.append(fairnessvirtuecount)
            fairnessvicelist.append(fairnessvicecount)
            fairnesslist.append(fairnessvicecount+fairnessvirtuecount)
            ingroupvirtuelist.append(ingroupvirtuecount)
            ingroupvicelist.append(ingroupvicecount)
            ingrouplist.append(ingroupvirtuecount + ingroupvicecount)
            authorityvirtuelist.append(authorityvirtuecount)
            authorityvicelist.append(authorityvicecount)
            authoritylist.append(authorityvicecount + authorityvirtuecount)
            purityvirtuelist.append(purityvirtuecount)
            purityvicelist.append(purityvicecount)
            puritylist.append(purityvicecount + purityvirtuecount)
            libertyvirtuelist.append(libertyvirtuecount)
            libertyvicelist.append(libertyvicecount)
            libertylist.append(libertyvicecount + libertyvirtuecount)
            moralgenlist.append(moralgencount)
            length.append(len(line))
        output = zip(ids,text,dates, favourites, retweets, quote, rt, morallist, harmvirtuelist, harmvicelist, harmlist, fairnessvirtuelist, fairnessvicelist, fairnesslist, ingroupvirtuelist, ingroupvicelist, ingrouplist, purityvirtuelist, purityvicelist, puritylist, authorityvirtuelist, authorityvicelist, authoritylist, libertyvirtuelist, libertyvicelist, libertylist, moralgenlist, length)
        outputfile = "/home/linda/manifestos/tweets/downloads/NL 2018/coded/{}_{}_coded.csv".format(name,lidmaatschap[name])
        print("Writing stuff to {}".format(outputfile))
        with open(outputfile, "w") as fo:
            writer=csv.writer(fo)
            writer.writerows(output)
# Out:
# now opening /home/linda/manifestos/tweets/downloads/NL 2018/tweets/thierrybaudet_FvD_tweets.csv
# Writing stuff to /home/linda/manifestos/tweets/downloads/NL 2018/coded/thierrybaudet_FvD_coded.csv
# now opening /home/linda/manifestos/tweets/downloads/NL 2018/tweets/LodewijkA_PvdA_tweets.csv
# Writing stuff to /home/linda/manifestos/tweets/downloads/NL 2018/coded/LodewijkA_PvdA_coded.csv
# now opening /home/linda/manifestos/tweets/downloads/NL 2018/tweets/tamaravanark_VVD_tweets.csv
# Writing stuff to /home/linda/manifestos/tweets/downloads/NL 2018/coded/tamaravanark_VVD_coded.csv
# now opening /home/linda/manifestos/tweets/downloads/NL 2018/tweets/MustafaAmhaouch_CDA_tweets.csv
# Writing stuff to /home/linda/manifestos/tweets/downloads/NL 2018/coded/MustafaAmhaouch_CDA_coded.csv
# now opening /home/linda/manifestos/tweets/downloads/NL 2018/tweets/khadijaArib_PvdA_tweets.csv
# Writing stuff to /home/linda/manifestos/tweets/downloads/NL 2018/coded/khadijaArib_PvdA_coded.csv
# now opening /home/linda/manifestos/tweets/downloads/NL 2018/tweets/F_azarkan_DENK_tweets.csv
# Writing stuff to /home/linda/manifestos/tweets/downloads/NL 2018/coded/azarkan_DENK_coded.csv
# now opening /home/linda/manifestos/tweets/downloads/NL 2018/tweets/bentebecker_VVD_tweets.csv
# Writing stuff to /home/linda/manifestos/tweets/downloads/NL 2018/coded/bentebecker_VVD_coded.csv
# now opening /home/linda/manifestos/tweets/downloads/NL 2018/tweets/MalikAzmani_VVD_tweets.csv
# Writing stuff to /home/linda/manifestos/tweets/downloads/NL 2018/coded/MalikAzmani_VVD_coded.csv
# now opening /home/linda/manifestos/tweets/downloads/NL 2018/tweets/FemkeMerel_PvdD_tweets.csv
# Writing stuff to /home/linda/manifestos/tweets/downloads/NL 2018/coded/FemkeMerel_PvdD_coded.csv

# %%
import glob
import pandas as pd
import numpy as np
import re
import os

path = "/home/linda/manifestos/tweets/downloads/NL 2018/coded/"
allfiles = glob.glob(os.path.join(path,"*.csv"))

peeps = [p.split('/')[-1].strip('.csv.') for p in allfiles]

names = [pp.split('_')[-3].strip() for pp in peeps]
parties = [pp.split('_')[-2].strip() for pp in peeps]

lidmaatschap = dict(zip(names,parties))
namefile = dict(zip(names,allfiles))

# %%
print(lidmaatschap)
print(namefile)
# Out:
# {'bentebecker': 'VVD', 'LodewijkA': 'PvdA', 'tamaravanark': 'VVD', 'FemkeMerel': 'PvdD', 'ZelYassini': 'VVD', 'azarkan': 'DENK', 'khadijaArib': 'PvdA', 'MustafaAmhaouch': 'CDA', 'thierrybaudet': 'FvD', 'MalikAzmani': 'VVD'}
# {'bentebecker': '/home/linda/manifestos/tweets/downloads/NL 2018/coded/bentebecker_VVD_coded.csv', 'LodewijkA': '/home/linda/manifestos/tweets/downloads/NL 2018/coded/LodewijkA_PvdA_coded.csv', 'tamaravanark': '/home/linda/manifestos/tweets/downloads/NL 2018/coded/tamaravanark_VVD_coded.csv', 'FemkeMerel': '/home/linda/manifestos/tweets/downloads/NL 2018/coded/FemkeMerel_PvdD_coded.csv', 'ZelYassini': '/home/linda/manifestos/tweets/downloads/NL 2018/coded/ZelYassini_VVD_coded.csv', 'azarkan': '/home/linda/manifestos/tweets/downloads/NL 2018/coded/azarkan_DENK_coded.csv', 'khadijaArib': '/home/linda/manifestos/tweets/downloads/NL 2018/coded/khadijaArib_PvdA_coded.csv', 'MustafaAmhaouch': '/home/linda/manifestos/tweets/downloads/NL 2018/coded/MustafaAmhaouch_CDA_coded.csv', 'thierrybaudet': '/home/linda/manifestos/tweets/downloads/NL 2018/coded/thierrybaudet_FvD_coded.csv', 'MalikAzmani': '/home/linda/manifestos/tweets/downloads/NL 2018/coded/MalikAzmani_VVD_coded.csv'}

# %%
np_array_list = []
data = []
for name in names:
    file_= namefile[name]
    df = pd.read_csv(file_,index_col=None, header=0)
    df['politicians'] = name
    df['party'] = lidmaatschap[name]
    data.append(df)
    np_array_list.append(df.as_matrix())

comb_np_array = np.vstack(np_array_list)
big_frame = pd.DataFrame(comb_np_array)

big_frame.columns = ['id','tweet','date', 'likes', 'retweets', 'quote', 'rt', 'morallist', 'harmvirtuelist', 'harmvicelist', 'harmlist', 'fairnessvirtuelist', 'fairnessvicelist',  'fairnesslist', 'ingroupvirtuelist', 'ingroupvicelist', 'ingrouplist', 'purityvirtuelist', 'purityvicelist', 'puritylist', 'authorityvirtuelist', 'authorityvicelist', 'authoritylist', 'libertyvirtuelist', 'libertyvicelist', 'libertylist', 'moralgenlist', 'length', 'name', 'party']

bf = big_frame.fillna(value = 0)

# %%
parties = pd.get_dummies(bf['party'])

bfd = pd.concat([bf, parties], axis=1)

# %%
for foundation in ['harmlist','puritylist','ingrouplist','authoritylist', 'fairnesslist', 'libertylist','moralgenlist',  'morallist']:
    print(foundation.upper())
    print(bfd[foundation].value_counts(sort=True, normalize=True))
    print('-------------------------------------------\n')
# Out:
# HARMLIST
# 0    0.901614
# 1    0.085742
# 2    0.011280
# 3    0.001325
# 4    0.000040
# Name: harmlist, dtype: float64
# -------------------------------------------
#
# PURITYLIST
# 0    0.977842
# 1    0.020592
# 2    0.001485
# 4    0.000080
# Name: puritylist, dtype: float64
# -------------------------------------------
#
# INGROUPLIST
# 0    0.942277
# 2    0.047046
# 1    0.007306
# 4    0.002890
# 3    0.000442
# 6    0.000040
# Name: ingrouplist, dtype: float64
# -------------------------------------------
#
# AUTHORITYLIST
# 0    0.933687
# 1    0.057603
# 2    0.007908
# 3    0.000763
# 6    0.000040
# Name: authoritylist, dtype: float64
# -------------------------------------------
#
# FAIRNESSLIST
# 0    0.965398
# 1    0.026895
# 2    0.006583
# 3    0.000723
# 4    0.000361
# 6    0.000040
# Name: fairnesslist, dtype: float64
# -------------------------------------------
#
# LIBERTYLIST
# 0    0.979809
# 1    0.018947
# 2    0.001204
# 3    0.000040
# Name: libertylist, dtype: float64
# -------------------------------------------
#
# MORALGENLIST
# 0    0.965559
# 1    0.025369
# 2    0.008390
# 3    0.000361
# 4    0.000281
# 6    0.000040
# Name: moralgenlist, dtype: float64
# -------------------------------------------
#
# MORALLIST
# 0    0.729367
# 1    0.196973
# 2    0.056278
# 3    0.012564
# 4    0.003813
# 5    0.000723
# 6    0.000161
# 7    0.000080
# 8    0.000040
# Name: morallist, dtype: float64
# -------------------------------------------

# %%
from statsmodels.formula.api import ols

myfittedregression = ols(formula = 'morallist ~ length + SP + GL + PvdD + PvdA + DENK + CU + CDA + SGP + VVD + PVV  ', data = bfd).fit()
print(myfittedregression.summary())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /usr/local/lib/python3.5/dist-packages/patsy/compat.py in call_and_wrap_exc(msg, origin, f, *args, **kwargs)
#     116     try:
# --> 117         return f(*args, **kwargs)
#     118     except Exception as e:
#
# /usr/local/lib/python3.5/dist-packages/patsy/eval.py in eval(self, expr, source_name, inner_namespace)
#     165         return eval(code, {}, VarLookupDict([inner_namespace]
# --> 166                                             + self._namespaces))
#     167
#
# <string> in <module>()
#
# NameError: name 'CU' is not defined
#
# The above exception was the direct cause of the following exception:
#
# PatsyError                                Traceback (most recent call last)
# <ipython-input-61-52fbc3f3eebe> in <module>()
#       1 from statsmodels.formula.api import ols
#       2
# ----> 3 myfittedregression = ols(formula = 'morallist ~ length + SP + GL + PvdD + PvdA + DENK + CU + CDA + SGP + VVD + PVV  ', data = bfd).fit()
#       4 print(myfittedregression.summary())
#
# /usr/local/lib/python3.5/dist-packages/statsmodels/base/model.py in from_formula(cls, formula, data, subset, drop_cols, *args, **kwargs)
#     153
#     154         tmp = handle_formula_data(data, None, formula, depth=eval_env,
# --> 155                                   missing=missing)
#     156         ((endog, exog), missing_idx, design_info) = tmp
#     157
#
# /usr/local/lib/python3.5/dist-packages/statsmodels/formula/formulatools.py in handle_formula_data(Y, X, formula, depth, missing)
#      63         if data_util._is_using_pandas(Y, None):
#      64             result = dmatrices(formula, Y, depth, return_type='dataframe',
# ---> 65                                NA_action=na_action)
#      66         else:
#      67             result = dmatrices(formula, Y, depth, return_type='dataframe',
#
# /usr/local/lib/python3.5/dist-packages/patsy/highlevel.py in dmatrices(formula_like, data, eval_env, NA_action, return_type)
#     308     eval_env = EvalEnvironment.capture(eval_env, reference=1)
#     309     (lhs, rhs) = _do_highlevel_design(formula_like, data, eval_env,
# --> 310                                       NA_action, return_type)
#     311     if lhs.shape[1] == 0:
#     312         raise PatsyError("model is missing required outcome variables")
#
# /usr/local/lib/python3.5/dist-packages/patsy/highlevel.py in _do_highlevel_design(formula_like, data, eval_env, NA_action, return_type)
#     163         return iter([data])
#     164     design_infos = _try_incr_builders(formula_like, data_iter_maker, eval_env,
# --> 165                                       NA_action)
#     166     if design_infos is not None:
#     167         return build_design_matrices(design_infos, data,
#
# /usr/local/lib/python3.5/dist-packages/patsy/highlevel.py in _try_incr_builders(formula_like, data_iter_maker, eval_env, NA_action)
#      68                                       data_iter_maker,
#      69                                       eval_env,
# ---> 70                                       NA_action)
#      71     else:
#      72         return None
#
# /usr/local/lib/python3.5/dist-packages/patsy/build.py in design_matrix_builders(termlists, data_iter_maker, eval_env, NA_action)
#     694                                                    factor_states,
#     695                                                    data_iter_maker,
# --> 696                                                    NA_action)
#     697     # Now we need the factor infos, which encapsulate the knowledge of
#     698     # how to turn any given factor into a chunk of data:
#
# /usr/local/lib/python3.5/dist-packages/patsy/build.py in _examine_factor_types(factors, factor_states, data_iter_maker, NA_action)
#     441     for data in data_iter_maker():
#     442         for factor in list(examine_needed):
# --> 443             value = factor.eval(factor_states[factor], data)
#     444             if factor in cat_sniffers or guess_categorical(value):
#     445                 if factor not in cat_sniffers:
#
# /usr/local/lib/python3.5/dist-packages/patsy/eval.py in eval(self, memorize_state, data)
#     564         return self._eval(memorize_state["eval_code"],
#     565                           memorize_state,
# --> 566                           data)
#     567
#     568     __getstate__ = no_pickling
#
# /usr/local/lib/python3.5/dist-packages/patsy/eval.py in _eval(self, code, memorize_state, data)
#     549                                  memorize_state["eval_env"].eval,
#     550                                  code,
# --> 551                                  inner_namespace=inner_namespace)
#     552
#     553     def memorize_chunk(self, state, which_pass, data):
#
# /usr/local/lib/python3.5/dist-packages/patsy/compat.py in call_and_wrap_exc(msg, origin, f, *args, **kwargs)
#     122                                  origin)
#     123             # Use 'exec' to hide this syntax from the Python 2 parser:
# --> 124             exec("raise new_exc from e")
#     125         else:
#     126             # In python 2, we just let the original exception escape -- better
#
# /usr/local/lib/python3.5/dist-packages/patsy/compat.py in <module>()
#
# PatsyError: Error evaluating factor: NameError: name 'CU' is not defined
#     morallist ~ length + SP + GL + PvdD + PvdA + DENK + CU + CDA + SGP + VVD + PVV
#                                                         ^^

# %%
from statsmodels.formula.api import ols

myfittedregression = ols(formula = 'morallist ~ length + SP + GL + PvdD + PvdA + DENK + CU + CDA + SGP + VVD + PVV  ', data = bfd).fit()
print(myfittedregression.summary())

myfittedregression = ols(formula = 'harmlist ~ length + SP + GL + PvdD + PvdA + DENK + CU + CDA + SGP + VVD + PVV', data = bfd).fit()
print(myfittedregression.summary())

myfittedregression = ols(formula = 'fairnesslist ~ length + SP + GL + PvdD + PvdA + DENK + CU + CDA + SGP + VVD + PVV  ', data = bfd).fit()
print(myfittedregression.summary())

myfittedregression = ols(formula = 'ingrouplist ~ length + SP + GL + PvdD + PvdA + DENK + CU + CDA + SGP + VVD + PVV  ', data = bfd).fit()
print(myfittedregression.summary())

myfittedregression = ols(formula = 'authoritylist ~ length + SP + GL + PvdD + PvdA + DENK + CU + CDA + SGP + VVD + PVV ', data = bfd).fit()
print(myfittedregression.summary())

myfittedregression = ols(formula = 'puritylist ~ length + SP + GL + PvdD + PvdA + DENK + CU + CDA + SGP + VVD + PVV ', data = bfd).fit()
print(myfittedregression.summary())

myfittedregression = ols(formula = 'libertylist ~ length + SP + GL + PvdD + PvdA + DENK + CU + CDA + SGP + VVD + PVV ', data = bfd).fit()
print(myfittedregression.summary())

myfittedregression = ols(formula = 'moralgenlist ~ length + SP + GL + PvdD + PvdA + DENK + CU + CDA + SGP + VVD + PVV  ', data = bfd).fit()
print(myfittedregression.summary())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /usr/local/lib/python3.5/dist-packages/patsy/compat.py in call_and_wrap_exc(msg, origin, f, *args, **kwargs)
#     116     try:
# --> 117         return f(*args, **kwargs)
#     118     except Exception as e:
#
# /usr/local/lib/python3.5/dist-packages/patsy/eval.py in eval(self, expr, source_name, inner_namespace)
#     165         return eval(code, {}, VarLookupDict([inner_namespace]
# --> 166                                             + self._namespaces))
#     167
#
# <string> in <module>()
#
# NameError: name 'CU' is not defined
#
# The above exception was the direct cause of the following exception:
#
# PatsyError                                Traceback (most recent call last)
# <ipython-input-62-a8d4e3aecd2d> in <module>()
#       1 from statsmodels.formula.api import ols
#       2
# ----> 3 myfittedregression = ols(formula = 'morallist ~ length + SP + GL + PvdD + PvdA + DENK + CU + CDA + SGP + VVD + PVV  ', data = bfd).fit()
#       4 print(myfittedregression.summary())
#       5
#
# /usr/local/lib/python3.5/dist-packages/statsmodels/base/model.py in from_formula(cls, formula, data, subset, drop_cols, *args, **kwargs)
#     153
#     154         tmp = handle_formula_data(data, None, formula, depth=eval_env,
# --> 155                                   missing=missing)
#     156         ((endog, exog), missing_idx, design_info) = tmp
#     157
#
# /usr/local/lib/python3.5/dist-packages/statsmodels/formula/formulatools.py in handle_formula_data(Y, X, formula, depth, missing)
#      63         if data_util._is_using_pandas(Y, None):
#      64             result = dmatrices(formula, Y, depth, return_type='dataframe',
# ---> 65                                NA_action=na_action)
#      66         else:
#      67             result = dmatrices(formula, Y, depth, return_type='dataframe',
#
# /usr/local/lib/python3.5/dist-packages/patsy/highlevel.py in dmatrices(formula_like, data, eval_env, NA_action, return_type)
#     308     eval_env = EvalEnvironment.capture(eval_env, reference=1)
#     309     (lhs, rhs) = _do_highlevel_design(formula_like, data, eval_env,
# --> 310                                       NA_action, return_type)
#     311     if lhs.shape[1] == 0:
#     312         raise PatsyError("model is missing required outcome variables")
#
# /usr/local/lib/python3.5/dist-packages/patsy/highlevel.py in _do_highlevel_design(formula_like, data, eval_env, NA_action, return_type)
#     163         return iter([data])
#     164     design_infos = _try_incr_builders(formula_like, data_iter_maker, eval_env,
# --> 165                                       NA_action)
#     166     if design_infos is not None:
#     167         return build_design_matrices(design_infos, data,
#
# /usr/local/lib/python3.5/dist-packages/patsy/highlevel.py in _try_incr_builders(formula_like, data_iter_maker, eval_env, NA_action)
#      68                                       data_iter_maker,
#      69                                       eval_env,
# ---> 70                                       NA_action)
#      71     else:
#      72         return None
#
# /usr/local/lib/python3.5/dist-packages/patsy/build.py in design_matrix_builders(termlists, data_iter_maker, eval_env, NA_action)
#     694                                                    factor_states,
#     695                                                    data_iter_maker,
# --> 696                                                    NA_action)
#     697     # Now we need the factor infos, which encapsulate the knowledge of
#     698     # how to turn any given factor into a chunk of data:
#
# /usr/local/lib/python3.5/dist-packages/patsy/build.py in _examine_factor_types(factors, factor_states, data_iter_maker, NA_action)
#     441     for data in data_iter_maker():
#     442         for factor in list(examine_needed):
# --> 443             value = factor.eval(factor_states[factor], data)
#     444             if factor in cat_sniffers or guess_categorical(value):
#     445                 if factor not in cat_sniffers:
#
# /usr/local/lib/python3.5/dist-packages/patsy/eval.py in eval(self, memorize_state, data)
#     564         return self._eval(memorize_state["eval_code"],
#     565                           memorize_state,
# --> 566                           data)
#     567
#     568     __getstate__ = no_pickling
#
# /usr/local/lib/python3.5/dist-packages/patsy/eval.py in _eval(self, code, memorize_state, data)
#     549                                  memorize_state["eval_env"].eval,
#     550                                  code,
# --> 551                                  inner_namespace=inner_namespace)
#     552
#     553     def memorize_chunk(self, state, which_pass, data):
#
# /usr/local/lib/python3.5/dist-packages/patsy/compat.py in call_and_wrap_exc(msg, origin, f, *args, **kwargs)
#     122                                  origin)
#     123             # Use 'exec' to hide this syntax from the Python 2 parser:
# --> 124             exec("raise new_exc from e")
#     125         else:
#     126             # In python 2, we just let the original exception escape -- better
#
# /usr/local/lib/python3.5/dist-packages/patsy/compat.py in <module>()
#
# PatsyError: Error evaluating factor: NameError: name 'CU' is not defined
#     morallist ~ length + SP + GL + PvdD + PvdA + DENK + CU + CDA + SGP + VVD + PVV
#                                                         ^^

# %%
bfd['moralratio'] = bfd['morallist']/bfd['length']
bfd['harmratio'] = bfd['harmlist']/bfd['length']
bfd['fairnessratio'] = bfd['fairnesslist']/bfd['length']
bfd['ingroupratio'] = bfd['ingrouplist']/bfd['length']
bfd['authorityratio'] = bfd['authoritylist']/bfd['length']
bfd['purityratio'] = bfd['puritylist']/bfd['length']
bfd['libertyratio'] = bfd['libertylist']/bfd['length']
bfd['moralgenratio'] = bfd['moralgenlist']/bfd['length']

# %%
myfittedregression = ols(formula = 'moralratio ~ SP + GL + PvdD + PvdA + DENK + CU + CDA + SGP + VVD + PVV  ', data = bfd).fit()
print(myfittedregression.summary())

myfittedregression = ols(formula = 'harmratio ~ SP + GL + PvdD + PvdA + DENK + CU + CDA + SGP + VVD + PVV  ', data = bfd).fit()
print(myfittedregression.summary())

myfittedregression = ols(formula = 'fairnessratio ~ SP + GL + PvdD + PvdA + DENK + CU + CDA + SGP + VVD + PVV   ', data = bfd).fit()
print(myfittedregression.summary())

myfittedregression = ols(formula = 'ingroupratio ~ SP + GL + PvdD + PvdA + DENK + CU + CDA + SGP + VVD + PVV  ', data = bfd).fit()
print(myfittedregression.summary())

myfittedregression = ols(formula = 'authorityratio ~ SP + GL + PvdD + PvdA + DENK + CU + CDA + SGP + VVD + PVV   ', data = bfd).fit()
print(myfittedregression.summary())

myfittedregression = ols(formula = 'purityratio ~   SP + GL + PvdD + PvdA + DENK + CU + CDA + SGP + VVD + PVV  ', data = bfd).fit()
print(myfittedregression.summary())

myfittedregression = ols(formula = 'libertyratio ~   SP + GL + PvdD + PvdA + DENK + CU + CDA + SGP + VVD + PVV   ', data = bfd).fit()
print(myfittedregression.summary())

myfittedregression = ols(formula = 'moralgenratio ~   SP + GL + PvdD + PvdA + DENK + CU + CDA + SGP + VVD + PVV  ', data = bfd).fit()
print(myfittedregression.summary())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /usr/local/lib/python3.5/dist-packages/patsy/compat.py in call_and_wrap_exc(msg, origin, f, *args, **kwargs)
#     116     try:
# --> 117         return f(*args, **kwargs)
#     118     except Exception as e:
#
# /usr/local/lib/python3.5/dist-packages/patsy/eval.py in eval(self, expr, source_name, inner_namespace)
#     165         return eval(code, {}, VarLookupDict([inner_namespace]
# --> 166                                             + self._namespaces))
#     167
#
# <string> in <module>()
#
# NameError: name 'CU' is not defined
#
# The above exception was the direct cause of the following exception:
#
# PatsyError                                Traceback (most recent call last)
# <ipython-input-64-1630ac5bc57b> in <module>()
# ----> 1 myfittedregression = ols(formula = 'moralratio ~ SP + GL + PvdD + PvdA + DENK + CU + CDA + SGP + VVD + PVV  ', data = bfd).fit()
#       2 print(myfittedregression.summary())
#       3
#       4 myfittedregression = ols(formula = 'harmratio ~ SP + GL + PvdD + PvdA + DENK + CU + CDA + SGP + VVD + PVV  ', data = bfd).fit()
#       5 print(myfittedregression.summary())
#
# /usr/local/lib/python3.5/dist-packages/statsmodels/base/model.py in from_formula(cls, formula, data, subset, drop_cols, *args, **kwargs)
#     153
#     154         tmp = handle_formula_data(data, None, formula, depth=eval_env,
# --> 155                                   missing=missing)
#     156         ((endog, exog), missing_idx, design_info) = tmp
#     157
#
# /usr/local/lib/python3.5/dist-packages/statsmodels/formula/formulatools.py in handle_formula_data(Y, X, formula, depth, missing)
#      63         if data_util._is_using_pandas(Y, None):
#      64             result = dmatrices(formula, Y, depth, return_type='dataframe',
# ---> 65                                NA_action=na_action)
#      66         else:
#      67             result = dmatrices(formula, Y, depth, return_type='dataframe',
#
# /usr/local/lib/python3.5/dist-packages/patsy/highlevel.py in dmatrices(formula_like, data, eval_env, NA_action, return_type)
#     308     eval_env = EvalEnvironment.capture(eval_env, reference=1)
#     309     (lhs, rhs) = _do_highlevel_design(formula_like, data, eval_env,
# --> 310                                       NA_action, return_type)
#     311     if lhs.shape[1] == 0:
#     312         raise PatsyError("model is missing required outcome variables")
#
# /usr/local/lib/python3.5/dist-packages/patsy/highlevel.py in _do_highlevel_design(formula_like, data, eval_env, NA_action, return_type)
#     163         return iter([data])
#     164     design_infos = _try_incr_builders(formula_like, data_iter_maker, eval_env,
# --> 165                                       NA_action)
#     166     if design_infos is not None:
#     167         return build_design_matrices(design_infos, data,
#
# /usr/local/lib/python3.5/dist-packages/patsy/highlevel.py in _try_incr_builders(formula_like, data_iter_maker, eval_env, NA_action)
#      68                                       data_iter_maker,
#      69                                       eval_env,
# ---> 70                                       NA_action)
#      71     else:
#      72         return None
#
# /usr/local/lib/python3.5/dist-packages/patsy/build.py in design_matrix_builders(termlists, data_iter_maker, eval_env, NA_action)
#     694                                                    factor_states,
#     695                                                    data_iter_maker,
# --> 696                                                    NA_action)
#     697     # Now we need the factor infos, which encapsulate the knowledge of
#     698     # how to turn any given factor into a chunk of data:
#
# /usr/local/lib/python3.5/dist-packages/patsy/build.py in _examine_factor_types(factors, factor_states, data_iter_maker, NA_action)
#     441     for data in data_iter_maker():
#     442         for factor in list(examine_needed):
# --> 443             value = factor.eval(factor_states[factor], data)
#     444             if factor in cat_sniffers or guess_categorical(value):
#     445                 if factor not in cat_sniffers:
#
# /usr/local/lib/python3.5/dist-packages/patsy/eval.py in eval(self, memorize_state, data)
#     564         return self._eval(memorize_state["eval_code"],
#     565                           memorize_state,
# --> 566                           data)
#     567
#     568     __getstate__ = no_pickling
#
# /usr/local/lib/python3.5/dist-packages/patsy/eval.py in _eval(self, code, memorize_state, data)
#     549                                  memorize_state["eval_env"].eval,
#     550                                  code,
# --> 551                                  inner_namespace=inner_namespace)
#     552
#     553     def memorize_chunk(self, state, which_pass, data):
#
# /usr/local/lib/python3.5/dist-packages/patsy/compat.py in call_and_wrap_exc(msg, origin, f, *args, **kwargs)
#     122                                  origin)
#     123             # Use 'exec' to hide this syntax from the Python 2 parser:
# --> 124             exec("raise new_exc from e")
#     125         else:
#     126             # In python 2, we just let the original exception escape -- better
#
# /usr/local/lib/python3.5/dist-packages/patsy/compat.py in <module>()
#
# PatsyError: Error evaluating factor: NameError: name 'CU' is not defined
#     moralratio ~ SP + GL + PvdD + PvdA + DENK + CU + CDA + SGP + VVD + PVV
#                                                 ^^

# %%
bfd['moraldummy'] = np.where(bfd['morallist']>0, '1', '0')
bfd['harmdummy'] = np.where(bfd['harmlist']>0, '1', '0')
bfd['fairnessdummy'] = np.where(bfd['fairnesslist']>0, '1', '0')
bfd['ingroupdummy'] = np.where(bfd['ingrouplist']>0, '1', '0')
bfd['authoritydummy'] = np.where(bfd['authoritylist']>0, '1', '0')
bfd['puritydummy'] = np.where(bfd['puritylist']>0, '1', '0')
bfd['libertydummy'] = np.where(bfd['libertylist']>0, '1', '0')
bfd['moralgendummy'] = np.where(bfd['moralgenlist']>0, '1', '0')

# %%
bfd.to_csv('/home/linda/manifestos/combined data/Dutch tweets 2018.csv')

# %%
bfd.to_csv('/home/linda/myrealcomputer/Dutch tweets 2018.csv')

# %%
# even kijken of dit ook werkt met totaltext

import csv
import re
from itertools import islice
import string


ids = []
likes = []
rt=[]
date=[]
image=[]
imtext = []
ttext = []
text = []

with open('/home/linda/manifestos/tweets/downloads/NL/Party leaders/test/geertwilderspvv_PVV_tweets_images.csv', encoding='utf-8',mode='r',newline='') as twitterlist:
    reader = csv.reader(twitterlist,delimiter=',')
    for row in csv.reader(islice(twitterlist, None)):
        ids.append(row[0])
        likes.append(row[1])
        rt.append(row[2])
        date.append(row[3])
        image.append(row[4])
        imtext.append(row[5])
        ttext.append(row[6])
        text.append(row[7])
    translate_table = dict((ord(char), None) for char in string.punctuation)   
    ttext = [t.translate(translate_table) for t in ttext]
    ttext = [t.lower() for t in ttext]
    ttext = [t.strip() for t in ttext if t.strip()!=""]
    ttext = [t.strip() for t in ttext if len(t)> 10]
    ttext = [' '.join(w for w in t.split() if w.lower() not in stopwords) for t in ttext]
    
print(ttext)
# Out:
# ['holland becomes hollandistan europe becomes eurabia leaders betray u…', 'disgusting hague becomes islamabad holland becomes hollandistan europe becomes eurabia leaders betra…', 'stay strong las vegas stay strong america lasvegas mandalaybay…', 'thoughts go victims injured stay strong las vegas stay strong america lasvegas…', 'stop islam many innocent people stopisla…', 'stop islam many innocent people stopislam nomore resistance', 'geweld eigen volk catalanreferendum', 'eu anno 2017 geweld eigen volk catalanreferendum', 'hear hear nomoreislam', 'muhammad example 1 billion muslims muhammad pedophile mass murderer terrorist…', 'mohammed voorbeeld 1 miljard moslims mohammed pedofiel massamoordenaar te…', '“police also confirmed isis flag seen suspects vehicle”', 'islam work “police also confirmed isis flag seen suspects vehicle”', 'islamistheproblem feweriess syllables truth islamic fs3a‘“alis 7ctal7aran islam islamk 511732135 i—‘clh‘kal islam mhh’ak islam islamcfascism islamcnazism rajkal islam islamifuf islam cww', 'genius islamistheproblem feweriess syllables truth islamic fs3a‘“alis 7ctal7aran islam islamk 511732135 i—‘clh‘kal islam mhh’ak islam islamcfascism islamcnazism rajkal islam islamifuf islam cww', 'malaysiagp verstappen mamaum mm', 'gefeliciteerd malaysiagp verstappen mamaum mm', 'chinese police order muslims hand copies koran', 'truth muhammad example 1 billion muslims muhammad pedophile mass murderer terror…', 'waarheid mohammed voorbeeld 1 miljard moslims mohammed pedofiel massamoordenaar…', 'profeet mohammed mag allemaal mohammed verkrachtte kindbruidje aisha negen jaar oud w…', 'inderdaad nl land islam g…', '“dat geert macht nooit gelukt” inderdaad nl land islam …', 'kamervragen samen ”an vooa mm“ pwvragen overname haagse thomaskerk moskee vugon man gin mwiigoii idoigm va «in mum mi upmam com ovum mun 52w cumin xug ovnomn «a menu mm bound mu boner nuglo um vmnm ’ii 2 mm mu em e um imbool um veer vomngng un ontolooalamllolun culluul vomngng nugl vnomnun coerce mon ovlna’imldwll anlunun ilvuu ummlcno’lo wulom r’ knonwu gamma non xug runs noon gononi aooiamluavyu anlunun innu mm 09 luginna pmalo mum la n wulom n r’ mm imammaroon la n union or’ em gamma crop ummn mm mu mu opengrmonwoa 01va mg unomdoluk mum» goon mun mu moon neg manna zullon mm mm aoluk bound momma ogromom lumen man onmooa cnnlolunluauu mu umngon zullon worm e um 1o union manna gmg omvolkoﬂ’', 'géén moskee ipv kerk kamervragen samen ”an vooa mm“ pwvragen overname haagse thomaskerk moskee vugon man gin mwiigoii idoigm va «in mum mi upmam com ovum mun 52w cumin xug ovnomn «a menu mm bound mu boner nuglo um vmnm ’ii 2 mm mu em e um imbool um veer vomngng un ontolooalamllolun culluul vomngng nugl vnomnun coerce mon ovlna’imldwll anlunun ilvuu ummlcno’lo wulom r’ knonwu gamma non xug runs noon gononi aooiamluavyu anlunun innu mm 09 luginna pmalo mum la n wulom n r’ mm imammaroon la n union or’ em gamma crop ummn mm mu mu opengrmonwoa 01va mg unomdoluk mum» goon mun mu moon neg manna zullon mm mm aoluk bound momma ogromom lumen man onmooa cnnlolunluauu mu umngon zullon worm e um 1o union manna gmg omvolkoﬂ’', '“the decision binding accept refugees muslim countries” hear hear nomoreislam', 'ais antwoord geemmldmpw wi“ km dont worry m“ fast son bitch fuck 3esus x fuck cristian fuck fuck mom fm q vedalm engeis 1g12 — 17 sep 2037', 'love islam hate own…', 'man man enorme angsthaas plucheplakker tijd stevige antiislamgeluid v…', '78 zegt hennis aftreden hexit', '7000 mensen gestemd 78 zegt hennis aftreden hexit', 'gmarchatimatova', 'vrijdag 3 november ga collega werkbezoek jihadhoofdstad europa molenbeekbrussel stopislam', 'freedomofspeech', 'ingestudeerde kletspraat gênant minister hennis beter eer zichzelf houden mete…', 'totale incompetentie ingestudeerde kletspraat gênant minister hennis beter eer zichzelf houden m…', 'population replaced european commission proud love islam hate their…', 'minister hennis defensie verantwoordelijkheid nemen aftreden opsta ...

# %%
    
    morallist=[]
    harmvirtuelist = []
    harmvicelist = []
    fairnessvirtuelist = []
    fairnessvicelist = []
    ingroupvirtuelist = []
    ingroupvicelist = []
    authorityvirtuelist = []
    authorityvicelist = []
    purityvirtuelist = []
    purityvicelist = []
    moralgenlist = []
    libertyvirtuelist = []
    libertyvicelist = []
    harmlist = []
    fairnesslist = []
    ingrouplist = []
    authoritylist = []
    puritylist = []
    libertylist=[]
    length=[]
    for line in ttext:
        moralcount=0
        harmvirtuecount=0
        harmvicecount=0
        fairnessvirtuecount=0
        fairnessvicecount=0
        ingroupvirtuecount=0
        ingroupvicecount=0
        authorityvirtuecount=0
        authorityvicecount=0
        purityvirtuecount=0
        purityvicecount=0
        libertyvirtuecount=0
        libertyvicecount=0
        moralgencount=0
        for pattern in moralityall:
            for word in line.split():
                if pattern[-1] == '*' and word.startswith(pattern[:-1]) or word == pattern:
                    moralcount+=1
            for pattern in harmvirtue:
                for word in line.split():
                    if pattern[-1] == '*' and word.startswith(pattern[:-1]) or word == pattern:
                        harmvirtuecount+=1
            for pattern in harmvice:
                for word in line.split():
                    if pattern[-1] == '*' and word.startswith(pattern[:-1]) or word == pattern:
                        harmvicecount+=1
            for pattern in fairnessvirtue:
                for word in line.split():
                    if pattern[-1] == '*' and word.startswith(pattern[:-1]) or word == pattern:
                        fairnessvirtuecount+=1
            for pattern in fairnessvice:
                for word in line.split():
                    if pattern[-1] == '*' and word.startswith(pattern[:-1]) or word == pattern:
                        fairnessvicecount+=1
            for pattern in ingroupvirtue:
                for word in line.split():
                    if pattern[-1] == '*' and word.startswith(pattern[:-1]) or word == pattern:
                        ingroupvirtuecount+=1
            for pattern in ingroupvice:
                for word in line.split():
                    if pattern[-1] == '*' and word.startswith(pattern[:-1]) or word == pattern:
                        ingroupvicecount+=1
            for pattern in authorityvirtue:
                for word in line.split():
                    if pattern[-1] == '*' and word.startswith(pattern[:-1]) or word == pattern:
                        authorityvirtuecount+=1
            for pattern in authorityvice:
                for word in line.split():
                    if pattern[-1] == '*' and word.startswith(pattern[:-1]) or word == pattern:
                        authorityvicecount+=1
            for pattern in purityvirtue:
                for word in line.split():
                    if pattern[-1] == '*' and word.startswith(pattern[:-1]) or word == pattern:
                        purityvirtuecount+=1
            for pattern in purityvice:
                for word in line.split():
                    if pattern[-1] == '*' and word.startswith(pattern[:-1]) or word == pattern:
                        purityvicecount+=1        
            for pattern in libertyvirtue:
                for word in line.split():
                    if pattern[-1] == '*' and word.startswith(pattern[:-1]) or word == pattern:
                        libertyvirtuecount+=1
            for pattern in libertyvice:
                for word in line.split():
                    if pattern[-1] == '*' and word.startswith(pattern[:-1]) or word == pattern:
                        libertyvicecount+=1
            for pattern in moralitygeneral:
                for word in line.split():
                    if pattern[-1] == '*' and word.startswith(pattern[:-1]) or word == pattern:
                        moralgencount+=1
            morallist.append(moralcount)
            harmvirtuelist.append(harmvirtuecount)
            harmvicelist.append(harmvicecount)
            harmlist.append(harmvicecount+harmvirtuecount)
            fairnessvirtuelist.append(fairnessvirtuecount)
            fairnessvicelist.append(fairnessvicecount)
            fairnesslist.append(fairnessvicecount+fairnessvirtuecount)
            ingroupvirtuelist.append(ingroupvirtuecount)
            ingroupvicelist.append(ingroupvicecount)
            ingrouplist.append(ingroupvirtuecount + ingroupvicecount)
            authorityvirtuelist.append(authorityvirtuecount)
            authorityvicelist.append(authorityvicecount)
            authoritylist.append(authorityvicecount + authorityvirtuecount)
            purityvirtuelist.append(purityvirtuecount)
            purityvicelist.append(purityvicecount)
            puritylist.append(purityvicecount + purityvirtuecount)
            libertyvirtuelist.append(libertyvirtuecount)
            libertyvicelist.append(libertyvicecount)
            libertylist.append(libertyvicecount + libertyvirtuecount)
            moralgenlist.append(moralgencount)
            length.append(len(line))
        output = zip(ids,text,dates, favourites, retweets,morallist, harmvirtuelist, harmvicelist, harmlist, fairnessvirtuelist, fairnessvicelist, fairnesslist, ingroupvirtuelist, ingroupvicelist, ingrouplist, purityvirtuelist, purityvicelist, puritylist, authorityvirtuelist, authorityvicelist, authoritylist, libertyvirtuelist, libertyvicelist, libertylist, moralgenlist, length)
        outputfile = "/home/linda/manifestos/tweets/downloads/NL/coded/{}_{}_coded.csv".format(name,lidmaatschap[name])
        print("Writing stuff to {}".format(outputfile))
        with open(outputfile, "w") as fo:
            writer=csv.writer(fo)
            writer.writerows(output)
