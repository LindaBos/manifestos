# %%
import nltk
nltk.download()

from nltk.stem.snowball import SnowballStemmer
stemmer=SnowballStemmer("dutch")

from nltk.corpus import stopwords
stopwords_ned = stopwords.words('dutch')
stopwords_eng = stopwords.words('english')
stopwords = stopwords_eng + stopwords_ned

import re

moraldic = open("/home/linda/manifestos/mf/dutch moral foundations dictionary ext.1.dic").read().replace("\t", "").replace("\s", "")


harmvirtue_ned = re.findall('([a-z]+\*?).*[0][1]', moraldic)
harmvice_ned = re.findall('([a-z]+\*?).*[0][2]', moraldic)
fairnessvirtue_ned = re.findall('([a-z]+\*?).*[0][3]', moraldic)
fairnessvice_ned = re.findall('([a-z]+\*?).*[0][4]', moraldic)
ingroupvirtue_ned = re.findall('([a-z]+\*?).*[0][5]', moraldic)
ingroupvice_ned = re.findall('([a-z]+\*?).*[0][6]', moraldic)
authorityvirtue_ned = re.findall('([a-z]+\*?).*[0][7]', moraldic)
authorityvice_ned = re.findall('([a-z]+\*?).*[0][8]', moraldic)
purityvirtue_ned = re.findall('([a-z]+\*?).*[0][9]', moraldic)
purityvice_ned = re.findall('([a-z]+\*?).*[1][0]', moraldic)
moralitygeneral_ned = re.findall('([a-z]+\*?).*[1][1]', moraldic)
libertyvirtue_ned = re.findall('([a-z]+\*?).*[1][2]', moraldic)
libertyvice_ned = re.findall('([a-z]+\*?).*[1][3]', moraldic)


moralityall_ned = re.findall('([a-z]+\*?).*[01-11]', moraldic)
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml

# %%
moraldic_eng = open("/home/linda/manifestos/mf/moral foundations dictionary ext.1.dic").read().replace("\t", "").replace("\s", "")


harmvirtue_eng = re.findall('([a-z]+\*?).*[0][1]', moraldic_eng)
harmvice_eng = re.findall('([a-z]+\*?).*[0][2]', moraldic_eng)
fairnessvirtue_eng = re.findall('([a-z]+\*?).*[0][3]', moraldic_eng)
fairnessvice_eng = re.findall('([a-z]+\*?).*[0][4]', moraldic_eng)
ingroupvirtue_eng = re.findall('([a-z]+\*?).*[0][5]', moraldic)
ingroupvice_eng = re.findall('([a-z]+\*?).*[0][6]', moraldic_eng)
authorityvirtue_eng = re.findall('([a-z]+\*?).*[0][7]', moraldic_eng)
authorityvice_eng = re.findall('([a-z]+\*?).*[0][8]', moraldic_eng)
purityvirtue_eng = re.findall('([a-z]+\*?).*[0][9]', moraldic_eng)
purityvice_eng = re.findall('([a-z]+\*?).*[1][0]', moraldic_eng)
moralitygeneral_eng = re.findall('([a-z]+\*?).*[1][1]', moraldic_eng)
libertyvirtue_eng = re.findall('([a-z]+\*?).*[1][2]', moraldic_eng)
libertyvice_eng = re.findall('([a-z]+\*?).*[1][3]', moraldic_eng)


moralityall_eng = re.findall('([a-z]+\*?).*[01-11]', moraldic_eng)

# %%
print(libertyvirtue_eng)
# Out:
# ['individual', 'individualit*', 'freedom', 'liberty', 'develop*', 'independen*', 'autonom*', 'independen*', 'self', 'identity']

# %%
harmvirtue = harmvirtue_eng + harmvirtue_ned
harmvice = harmvice_eng + harmvice_ned
fairnessvirtue = fairnessvirtue_eng + fairnessvirtue_ned
fairnessvice = fairnessvice_eng + fairnessvice_ned
ingroupvirtue = ingroupvirtue_eng + ingroupvirtue_ned
ingroupvice = ingroupvice_eng + ingroupvice_ned
authorityvirtue = authorityvirtue_eng + authorityvirtue_ned
authorityvice = authorityvice_eng + authorityvice_ned
purityvirtue = purityvirtue_eng + purityvirtue_ned
purityvice = purityvice_eng + purityvice_ned
libertyvirtue = libertyvirtue_eng + libertyvirtue_ned
libertyvice = libertyvice_eng + libertyvice_ned
moralitygeneral = moralitygeneral_eng + moralitygeneral_ned
moralityall = moralityall_eng + moralityall_ned

# %%
print(names)
# Out:
# ['PVV', 'JoelVoordewind', 'RidderDionGraus', 'GraafdeMachiel', 'gjfpopken', 'HenkKrol', 'LammertvanRaan', 'AnneKuik', 'gertjansegers', 'ZelYassini', 'Martijncda', 'DilanYesilgoz', 'rvanaalst', 'thierrybaudet', 'SandraBeckerman', 'ZihniOzdil', 'bartvankent', 'KopsPVV', 'HalbeZijlstra', 'bvantwout', 'SvVeldhoven', 'bartsnels', 'FrankFutselaar', 'RaymondKnops', 'ChrisvanDamCDA', 'vanrooijen', 'pvv', 'BisschopRoelof', 'foortvanoosten', 'Middendorp', 'piadijkstra', 'LodewijkA', 'dijkvangijs', 'CorinneEllemeet', 'attjekuiken', 'harmbeertema', 'keesvdstaaij', 'arladikfaber', 'kirstenvdhul', 'SalimaBelhaj', 'KarenGerbrands1', 'mariannethieme', 'AntjeDiertens', 'JaspervanDijkSP', 'dijksma', 'tamaravanark', 'mulder', 'JessicaVanEijs', 'SvenKoopmansVVD', 'FleurAgemaPVV', 'VickyMaeijer', 'leondejong', 'KeesVee', 'TjeerdD66', 'MvanToorenburg', 'MustafaAmhaouch', 'erikziengs', 'MonaKeijzer', 'HanTenBroeke', 'GL', 'dijkhoff', 'RenePetersOss', 'ivanengelshoven', 'RoaldLinde', 'markrutte', 'WassenbergFrank', 'DennisWiersma', 'wsjoerdsma', 'MarijnissenL', 'wkoolmees', 'JeanineHennis', 'jesseklaver', 'HankeBruinsSlot', 'markharbers', 'rikgrashoff', 'AgnesMulderCDA', 'CemLacin', 'kathalijne', 'GidiMarkuszower', 'remcovvd', 'BarbaraVVD', 'danielkoerhuis', 'Dijsselbloem', 'ArneWeverling', 'Lisawesterveld', 'RenskeLeijten', 'JacoGeurts', 'harryvdmolen', 'ybrandbuma', 'Thiddema', 'edgarmulder1', 'TomvanderLee', 'andrebosman', 'RobJetten', 'ockjetellegen', 'elcukozturknl', 'khadijaArib', 'azarkan', 'geertwilderspvv', 'Hermans', 'mvonmartels', 'SadetKarabulut', 'estherouwehand', 'arolaschouten', 'MinPres', 'Meenen', 'APechtold', 'anweyenberg', 'jpaternotte', 'elbertdijkgraaf', 'henknijboer', 'RaymondRoonPVV', 'bentebecker', 'CvanBrenk', 'tunahankuzu', 'lindavoortman', 'RensRaemakers', 'BramvanOjikGL', 'PieterHeerma', 'Worsdorfer', 'MalikAzmani', 'michelrog', 'LeonieSazias', 'emileroemer', 'GroenLiesbeth', 'aukjedevries', 'lilianhelderpvv', 'PieterOmtzigt', 'GroothuizenD66', 'NevinOzutok', 'nijkerken', 'ErikRonnes', 'Bergkamp', 'peterkwint', 'MaartenHijink', 'arnorutte', 'eppobruins', 'achrafboualid66', 'SanderDekker', 'JobaCDA', 'FemkeMerel', 'HelmaLodders', 'NineKooiman', 'IsabelleDiks']

# %%
import csv
from glob import glob
import re
from itertools import islice
import string

names=[]
parties=[]
lidmaatschap = {}




alltweets = glob("/home/linda/manifestos/tweets/downloads/NL/*.csv")
peeps = [p.split('/')[-1].strip('.csv.') for p in alltweets]

names = [pp.split('_')[-3].strip() for pp in peeps]
parties = [pp.split('_')[-2].strip() for pp in peeps]

lidmaatschap = dict(zip(names,parties))
filenames = dict(zip(names, alltweets))


for name in names:
    ids=[]
    favourites=[]
    retweets=[]
    dates=[]
    text=[]
    file = filenames[name]
    print("now opening", file)
    with open(file) as fi:
        reader = csv.reader(fi,delimiter=',')
        for row in csv.reader(islice(fi, None)):
            ids.append(row[0])
            favourites.append(row[1])
            retweets.append(row[2])
            dates.append(row[3])
            text.append(row[4]) 
        translate_table = dict((ord(char), None) for char in string.punctuation)   
        text = [t.translate(translate_table) for t in text]
        text = [t.lower() for t in text]
        text = [t.strip() for t in text if t.strip()!=""]
        text = [t.strip() for t in text if len(t)> 10]
        text = [' '.join(w for w in t.split() if w.lower() not in stopwords) for t in text]
        morallist=[]
        harmvirtuelist = []
        harmvicelist = []
        fairnessvirtuelist = []
        fairnessvicelist = []
        ingroupvirtuelist = []
        ingroupvicelist = []
        authorityvirtuelist = []
        authorityvicelist = []
        purityvirtuelist = []
        purityvicelist = []
        moralgenlist = []
        libertyvirtuelist = []
        libertyvicelist = []
        harmlist = []
        fairnesslist = []
        ingrouplist = []
        authoritylist = []
        puritylist = []
        libertylist=[]
        length=[]
        for line in text:
            moralcount=0
            harmvirtuecount=0
            harmvicecount=0
            fairnessvirtuecount=0
            fairnessvicecount=0
            ingroupvirtuecount=0
            ingroupvicecount=0
            authorityvirtuecount=0
            authorityvicecount=0
            purityvirtuecount=0
            purityvicecount=0
            libertyvirtuecount=0
            libertyvicecount=0
            moralgencount=0
            for pattern in moralityall:
                for word in line.split():
                    if pattern[-1] == '*' and word.startswith(pattern[:-1]) or word == pattern:
                        moralcount+=1
            for pattern in harmvirtue:
                for word in line.split():
                    if pattern[-1] == '*' and word.startswith(pattern[:-1]) or word == pattern:
                        harmvirtuecount+=1
            for pattern in harmvice:
                for word in line.split():
                    if pattern[-1] == '*' and word.startswith(pattern[:-1]) or word == pattern:
                        harmvicecount+=1
            for pattern in fairnessvirtue:
                for word in line.split():
                    if pattern[-1] == '*' and word.startswith(pattern[:-1]) or word == pattern:
                        fairnessvirtuecount+=1
            for pattern in fairnessvice:
                for word in line.split():
                    if pattern[-1] == '*' and word.startswith(pattern[:-1]) or word == pattern:
                        fairnessvicecount+=1
            for pattern in ingroupvirtue:
                for word in line.split():
                    if pattern[-1] == '*' and word.startswith(pattern[:-1]) or word == pattern:
                        ingroupvirtuecount+=1
            for pattern in ingroupvice:
                for word in line.split():
                    if pattern[-1] == '*' and word.startswith(pattern[:-1]) or word == pattern:
                        ingroupvicecount+=1
            for pattern in authorityvirtue:
                for word in line.split():
                    if pattern[-1] == '*' and word.startswith(pattern[:-1]) or word == pattern:
                        authorityvirtuecount+=1
            for pattern in authorityvice:
                for word in line.split():
                    if pattern[-1] == '*' and word.startswith(pattern[:-1]) or word == pattern:
                        authorityvicecount+=1
            for pattern in purityvirtue:
                for word in line.split():
                    if pattern[-1] == '*' and word.startswith(pattern[:-1]) or word == pattern:
                        purityvirtuecount+=1
            for pattern in purityvice:
                for word in line.split():
                    if pattern[-1] == '*' and word.startswith(pattern[:-1]) or word == pattern:
                        purityvicecount+=1        
            for pattern in libertyvirtue:
                for word in line.split():
                    if pattern[-1] == '*' and word.startswith(pattern[:-1]) or word == pattern:
                        libertyvirtuecount+=1
            for pattern in libertyvice:
                for word in line.split():
                    if pattern[-1] == '*' and word.startswith(pattern[:-1]) or word == pattern:
                        libertyvicecount+=1
            for pattern in moralitygeneral:
                for word in line.split():
                    if pattern[-1] == '*' and word.startswith(pattern[:-1]) or word == pattern:
                        moralgencount+=1
            morallist.append(moralcount)
            harmvirtuelist.append(harmvirtuecount)
            harmvicelist.append(harmvicecount)
            harmlist.append(harmvicecount+harmvirtuecount)
            fairnessvirtuelist.append(fairnessvirtuecount)
            fairnessvicelist.append(fairnessvicecount)
            fairnesslist.append(fairnessvicecount+fairnessvirtuecount)
            ingroupvirtuelist.append(ingroupvirtuecount)
            ingroupvicelist.append(ingroupvicecount)
            ingrouplist.append(ingroupvirtuecount + ingroupvicecount)
            authorityvirtuelist.append(authorityvirtuecount)
            authorityvicelist.append(authorityvicecount)
            authoritylist.append(authorityvicecount + authorityvirtuecount)
            purityvirtuelist.append(purityvirtuecount)
            purityvicelist.append(purityvicecount)
            puritylist.append(purityvicecount + purityvirtuecount)
            libertyvirtuelist.append(libertyvirtuecount)
            libertyvicelist.append(libertyvicecount)
            libertylist.append(libertyvicecount + libertyvirtuecount)
            moralgenlist.append(moralgencount)
            length.append(len(line))
        output = zip(ids,text,dates, favourites, retweets,morallist, harmvirtuelist, harmvicelist, harmlist, fairnessvirtuelist, fairnessvicelist, fairnesslist, ingroupvirtuelist, ingroupvicelist, ingrouplist, purityvirtuelist, purityvicelist, puritylist, authorityvirtuelist, authorityvicelist, authoritylist, libertyvirtuelist, libertyvicelist, libertylist, moralgenlist, length)
        outputfile = "/home/linda/manifestos/tweets/downloads/NL/coded/{}_{}_coded.csv".format(name,lidmaatschap[name])
        print("Writing stuff to {}".format(outputfile))
        with open(outputfile, "w") as fo:
            writer=csv.writer(fo)
            writer.writerows(output)
# Out:
# now opening /home/linda/manifestos/tweets/downloads/NL/geertwilderspvv_PVV_tweets.csv
# Writing stuff to /home/linda/manifestos/tweets/downloads/NL/coded/geertwilderspvv_PVV_coded.csv
# now opening /home/linda/manifestos/tweets/downloads/NL/Sophie_Hermans_VVD_tweets.csv
# Writing stuff to /home/linda/manifestos/tweets/downloads/NL/coded/Hermans_VVD_coded.csv
# now opening /home/linda/manifestos/tweets/downloads/NL/mvonmartels_CDA_tweets.csv
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-23-ecbe0ce1fc06> in <module>()
#      82             for pattern in moralityall:
#      83                 for word in line.split():
# ---> 84                     if pattern[-1] == '*' and word.startswith(pattern[:-1]) or word == pattern:
#      85                         moralcount+=1
#      86             for pattern in harmvirtue:
#
# KeyboardInterrupt:

# %%
import glob
import pandas as pd
import numpy as np
import re
import os

path = "/home/linda/manifestos/tweets/downloads/NL/coded/"
allfiles = glob.glob(os.path.join(path,"*.csv"))

peeps = [p.split('/')[-1].strip('.csv.') for p in alltweets]

names = [pp.split('_')[-3].strip() for pp in peeps]
parties = [pp.split('_')[-2].strip() for pp in peeps]

lidmaatschap = dict(zip(names,parties))
namefile = dict(zip(names,allfiles))

# %%
print(lidmaatschap)
print(namefile)
# Out:
# {'Middendorp': 'VVD', 'nijkerken': 'VVD', 'LodewijkA': 'PvdA', 'IsabelleDiks': 'GL', 'MustafaAmhaouch': 'CDA', 'HankeBruinsSlot': 'CDA', 'SvenKoopmansVVD': 'VVD', 'ZihniOzdil': 'GL', 'gjfpopken': 'PVV', 'LammertvanRaan': 'PvdD', 'RaymondKnops': 'CDA', 'mariannethieme': 'PvdD', 'khadijaArib': 'PvdA', 'michelrog': 'CDA', 'HelmaLodders': 'VVD', 'WassenbergFrank': 'PvdD', 'lilianhelderpvv': 'PVV', 'aukjedevries': 'VVD', 'KeesVee': 'D66', 'TomvanderLee': 'GL', 'Hermans': 'VVD', 'azarkan': 'DENK', 'BramvanOjikGL': 'GL', 'ArneWeverling': 'VVD', 'HalbeZijlstra': 'VVD', 'elbertdijkgraaf': 'SGP', 'ZelYassini': 'VVD', 'FrankFutselaar': 'SP', 'GroenLiesbeth': 'GL', 'SvVeldhoven': 'D66', 'Martijncda': 'CDA', 'wsjoerdsma': 'D66', 'LeonieSazias': '50PLUS', 'JeanineHennis': 'VVD', 'keesvdstaaij': 'SGP', 'Dijsselbloem': 'PvdA', 'DennisWiersma': 'VVD', 'erikziengs': 'VVD', 'PieterOmtzigt': 'CDA', 'piadijkstra': 'D66', 'kathalijne': 'GL', 'MarijnissenL': 'SP', 'MonaKeijzer': 'CDA', 'andrebosman': 'VVD', 'KarenGerbrands1': 'PVV', 'arladikfaber': 'CU', 'JaspervanDijkSP': 'SP', 'JessicaVanEijs': 'D66', 'RidderDionGraus': 'PVV', 'lindavoortman': 'GL', 'PVV': 'PVV', 'achrafboualid66': 'D66', 'SadetKarabulut': 'SP', 'bartvankent': 'SP', 'MalikAzmani': 'VVD', 'mulder': 'VVD', 'CemLacin': 'SP', 'Meenen': 'D66', 'bartsnels': 'GL', 'ivanengelshoven': 'D66', 'RobJetten': 'D66', 'arolaschouten': 'CU', 'Thiddema': 'FvD', 'RenePetersOss': 'CDA', 'CorinneEllemeet': 'GL', 'VickyMaeijer': 'PVV', 'rvanaalst': 'PVV', 'Lisawesterveld': 'GL', 'AntjeDiertens': 'D66', 'gertjansegers': 'CU', 'NineKooiman': 'SP', 'AnneKuik': 'CDA', 'tunahankuzu': 'DENK', 'geertwilderspvv': 'PVV', 'emileroemer': 'SP', 'BisschopRoelof': 'SGP', 'foortvanoosten': 'VVD', 'MaartenHijink': 'SP', 'harmbeertema': 'PVV', 'FemkeMerel': 'PvdD', 'jpaternotte': 'D66', 'FleurAgemaPVV': 'PVV', 'BarbaraVVD': 'VVD', 'GraafdeMachiel': 'PVV', 'edgarmulder1': 'PVV', 'KopsPVV': 'PVV', 'JobaCDA': 'CDA', 'GroothuizenD66': 'D66', 'dijkvangijs': 'PvdA', 'ockjetellegen': 'VVD', 'SalimaBelhaj': 'D66', 'JacoGeurts': 'CDA', 'ChrisvanDamCDA': 'CDA', 'SandraBeckerman': 'SP', 'HenkKrol': '50PLUS', 'ErikRonnes': 'CDA', 'MvanToorenburg': 'CDA', 'APechtold': 'D66', 'arnorutte': 'VVD', 'vanrooijen': '50PLUS', 'kirstenvdhul': 'PvdA', 'markharbers': 'VVD', 'CvanBrenk': '50PLUS', 'DilanYesilgoz': 'VVD', 'tamaravanark': 'VVD', 'bvantwout': 'VVD', 'TjeerdD66': 'D66', 'anweyenberg': 'D66', 'thierrybaudet': 'FvD', 'AgnesMulderCDA': 'CDA', 'leondejong': 'PVV', 'RaymondRoonPVV': 'PVV', 'danielkoerhuis': 'VVD', 'dijkhoff': 'VVD', 'GidiMarkuszower': 'PVV', 'estherouwehand': 'PvdD', 'Worsdorfer': 'VVD', 'harryvdmolen': 'CDA', 'henknijboer': 'PvdA', 'PieterHeerma': 'CDA', 'markrutte': 'VVD', 'dijksma': 'PvdA', 'RensRaemakers': 'D66', 'SanderDekker': 'VVD', 'JoelVoordewind': 'CU', 'HanTenBroeke': 'VVD', 'pvv': 'PVV', 'attjekuiken': 'PvdA', 'peterkwint': 'SP', 'eppobruins': 'CU', 'remcovvd': 'VVD', 'MinPres': 'VVD', 'mvonmartels': 'CDA', 'NevinOzutok': 'GL', 'RenskeLeijten': 'SP', 'Bergkamp': 'D66', 'bentebecker': 'VVD', 'ybrandbuma': 'CDA', 'RoaldLinde': 'VVD', 'wkoolmees': 'D66', 'jesseklaver': 'GL', 'elcukozturknl': 'DENK', 'GL': 'GL', 'rikgrashoff': 'GL'}
# {'Middendorp': '/home/linda/manifestos/tweets/downloads/NL/coded/JeanineHennis_VVD_coded.csv', 'nijkerken': '/home/linda/manifestos/tweets/downloads/NL/coded/TjeerdD66_D66_coded.csv', 'LodewijkA': '/home/linda/manifestos/tweets/downloads/NL/coded/Thiddema_FvD_coded.csv', 'IsabelleDiks': '/home/linda/manifestos/tweets/downloads/NL/coded/SanderDekker_VVD_coded.csv', 'MustafaAmhaouch': '/home/linda/manifestos/tweets/downloads/NL/coded/Worsdorfer_VVD_coded.csv', 'HankeBruinsSlot': '/home/linda/manifestos/tweets/downloads/NL/coded/arladikfaber_CU_coded.csv', 'SvenKoopmansVVD': '/home/linda/manifestos/tweets/downloads/NL/coded/CorinneEllemeet_GL_coded.csv', 'ZihniOzdil': '/home/linda/manifestos/tweets/downloads/NL/coded/kirstenvdhul_PvdA_coded.csv', 'gjfpopken': '/home/linda/manifestos/tweets/downloads/NL/coded/jesseklaver_GL_coded.csv', 'LammertvanRaan': '/home/linda/manifestos/tweets/downloads/NL/coded/MonaKeijzer_CDA_coded.csv', 'RaymondKnops': '/home/linda/manifestos/tweets/downloads/NL/coded/JobaCDA_CDA_coded.csv', 'mariannethieme': '/home/linda/manifestos/tweets/downloads/NL/coded/erikziengs_VVD_coded.csv', 'khadijaArib': '/home/linda/manifestos/tweets/downloads/NL/coded/piadijkstra_D66_coded.csv', 'michelrog': '/home/linda/manifestos/tweets/downloads/NL/coded/FleurAgemaPVV_PVV_coded.csv', 'HelmaLodders': '/home/linda/manifestos/tweets/downloads/NL/coded/Meenen_D66_coded.csv', 'WassenbergFrank': '/home/linda/manifestos/tweets/downloads/NL/coded/JoelVoordewind_CU_coded.csv', 'lilianhelderpvv': '/home/linda/manifestos/tweets/downloads/NL/coded/khadijaArib_PvdA_coded.csv', 'aukjedevries': '/home/linda/manifestos/tweets/downloads/NL/coded/ybrandbuma_CDA_coded.csv', 'KeesVee': '/home/linda/manifestos/tweets/downloads/NL/coded/ChrisvanDamCDA_CDA_coded.csv', 'TomvanderLee': '/home/linda/manifestos/tweets/downloads/NL/coded/GroothuizenD66_D66_coded.csv', 'Hermans': '/home/linda/manifestos/tweets/downloads/NL/coded/GL_GL_coded.csv', 'azarkan': '/home/linda/manifestos/tweets/downloads/NL/coded/FrankFutselaar_SP_coded.csv', 'BramvanOjikGL': '/home/linda/manifestos/tweets/downloads/NL/coded/LodewijkA_pvda_coded.csv', 'ArneWeverling': '/home/linda/manifestos/tweets/downloads/NL/coded/wsjoerdsma_D66_coded.csv', 'HalbeZijlstra': '/home/linda/manifestos/tweets/downloads/NL/coded/achrafboualid66_D66_coded.csv', 'elbertdijkgraaf': '/home/linda/manifestos/tweets/downloads/NL/coded/RenePetersOss_CDA_coded.csv', 'ZelYassini': '/home/linda/manifestos/tweets/downloads/NL/coded/CemLacin_SP_coded.csv', 'FrankFutselaar': '/home/linda/manifestos/tweets/downloads/NL/coded/RoaldLinde_VVD_coded.csv', 'GroenLiesbeth': '/home/linda/manifestos/tweets/downloads/NL/coded/FemkeMerel_PvdD_coded.csv', 'SvVeldhoven': '/home/linda/manifestos/tweets/downloads/NL/coded/danielkoerhuis_VVD_coded.csv', 'Martijncda': '/home/linda/manifestos/tweets/downloads/NL/coded/bartsnels_GL_coded.csv', 'wsjoerdsma': '/home/linda/manifestos/tweets/downloads/NL/coded/MaartenHijink_SP_coded.csv', 'LeonieSazias': '/home/linda/manifestos/tweets/downloads/NL/coded/ArneWeverling_VVD_coded.csv', 'JeanineHennis': '/home/linda/manifestos/tweets/downloads/NL/coded/AntjeDiertens_D66_coded.csv', 'keesvdstaaij': '/home/linda/manifestos/tweets/downloads/NL/coded/bvantwout_VVD_coded.csv', 'Dijsselbloem': '/home/linda/manifestos/tweets/downloads/NL/coded/JaspervanDijkSP_SP_coded.csv', 'DennisWiersma': '/home/linda/manifestos/tweets/downloads/NL/coded/HenkKrol_50PLUS_coded.csv', 'erikziengs': '/home/linda/manifestos/tweets/downloads/NL/coded/TomvanderLee_GL_coded.csv', 'PieterOmtzigt': '/home/linda/manifestos/tweets/downloads/NL/coded/emileroemer_sp_coded.csv', 'piadijkstra': '/home/linda/manifestos/tweets/downloads/NL/coded/michelrog_CDA_coded.csv', 'kathalijne': '/home/linda/manifestos/tweets/downloads/NL/coded/bentebecker_VVD_coded.csv', 'MarijnissenL': '/home/linda/manifestos/tweets/downloads/NL/coded/gertjansegers_CU_coded.csv', 'MonaKeijzer': '/home/linda/manifestos/tweets/downloads/NL/coded/Eri ...

# %%
np_array_list = []
data = []
for name in names:
    file_= namefile[name]
    df = pd.read_csv(file_,index_col=None, header=0)
    df['politicians'] = name
    df['party'] = lidmaatschap[name]
    data.append(df)
    np_array_list.append(df.as_matrix())

comb_np_array = np.vstack(np_array_list)
big_frame = pd.DataFrame(comb_np_array)

big_frame.columns = ['id','tweet','date', 'likes', 'retweets', 'morallist', 'harmvirtuelist', 'harmvicelist', 'harmlist', 'fairnessvirtuelist', 'fairnessvicelist',  'fairnesslist', 'ingroupvirtuelist', 'ingroupvicelist', 'ingrouplist', 'purityvirtuelist', 'purityvicelist', 'puritylist', 'authorityvirtuelist', 'authorityvicelist', 'authoritylist', 'libertyvirtuelist', 'libertyvicelist', 'libertylist', 'moralgenlist', 'length', 'name', 'party']

bf = big_frame.fillna(value = 0)

# %%
parties = pd.get_dummies(bf['party'])

bfd = pd.concat([bf, parties], axis=1)

# %%
for foundation in ['harmlist','puritylist','ingrouplist','authoritylist', 'fairnesslist', 'libertylist','moralgenlist',  'morallist']:
    print(foundation.upper())
    print(bfd[foundation].value_counts(sort=True, normalize=True))
    print('-------------------------------------------\n')
# Out:
# HARMLIST
# 0    0.904377
# 1    0.084090
# 2    0.010182
# 3    0.001178
# 4    0.000153
# 5    0.000019
# Name: harmlist, dtype: float64
# -------------------------------------------
#
# PURITYLIST
# 0    0.976298
# 1    0.022088
# 2    0.001513
# 3    0.000096
# 4    0.000005
# Name: puritylist, dtype: float64
# -------------------------------------------
#
# INGROUPLIST
# 0    0.951226
# 2    0.039823
# 1    0.006753
# 4    0.001724
# 3    0.000364
# 6    0.000077
# 5    0.000019
# 8    0.000014
# Name: ingrouplist, dtype: float64
# -------------------------------------------
#
# AUTHORITYLIST
# 0    0.934559
# 1    0.057151
# 2    0.007538
# 3    0.000570
# 4    0.000148
# 5    0.000019
# 6    0.000010
# 7    0.000005
# Name: authoritylist, dtype: float64
# -------------------------------------------
#
# FAIRNESSLIST
# 0    0.967859
# 1    0.026710
# 2    0.004626
# 3    0.000651
# 4    0.000125
# 5    0.000019
# 6    0.000010
# Name: fairnesslist, dtype: float64
# -------------------------------------------
#
# LIBERTYLIST
# 0    0.979440
# 1    0.019148
# 2    0.001351
# 3    0.000057
# 4    0.000005
# Name: libertylist, dtype: float64
# -------------------------------------------
#
# MORALGENLIST
# 0    0.967102
# 1    0.026643
# 2    0.005805
# 3    0.000326
# 4    0.000115
# 5    0.000010
# Name: moralgenlist, dtype: float64
# -------------------------------------------
#
# MORALLIST
# 0    0.743188
# 1    0.192156
# 2    0.048669
# 3    0.011609
# 4    0.003233
# 5    0.000833
# 6    0.000254
# 7    0.000038
# 9    0.000010
# 8    0.000010
# Name: morallist, dtype: float64
# -------------------------------------------

# %%
from statsmodels.formula.api import ols

myfittedregression = ols(formula = 'morallist ~ length + SP + GL + PvdD + PvdA + DENK + CU + CDA + SGP + VVD + PVV  ', data = bfd).fit()
print(myfittedregression.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              morallist   R-squared:                       0.070
# Model:                            OLS   Adj. R-squared:                  0.070
# Method:                 Least Squares   F-statistic:                     1421.
# Date:                Thu, 21 Sep 2017   Prob (F-statistic):               0.00
# Time:                        13:31:16   Log-Likelihood:            -2.0729e+05
# No. Observations:              208799   AIC:                         4.146e+05
# Df Residuals:                  208787   BIC:                         4.147e+05
# Df Model:                          11
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.0632      0.005    -13.439      0.000      -0.072      -0.054
# length         0.0063   5.09e-05    122.979      0.000       0.006       0.006
# SP             0.0747      0.006     11.837      0.000       0.062       0.087
# GL             0.0837      0.006     14.158      0.000       0.072       0.095
# PvdD           0.1166      0.008     15.339      0.000       0.102       0.131
# PvdA           0.0535      0.007      7.958      0.000       0.040       0.067
# DENK           0.0219      0.011      2.039      0.041       0.001       0.043
# CU             0.0449      0.008      5.361      0.000       0.028       0.061
# CDA            0.0138      0.005      2.571      0.010       0.003       0.024
# SGP            0.0489      0.010      4.996      0.000       0.030       0.068
# VVD            0.0645      0.005     14.090      0.000       0.055       0.073
# PVV            0.0203      0.005      3.735      0.000       0.010       0.031
# ==============================================================================
# Omnibus:                   103693.622   Durbin-Watson:                   1.848
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           736861.673
# Skew:                           2.309   Prob(JB):                         0.00
# Kurtosis:                      10.961   Cond. No.                         610.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
from statsmodels.formula.api import ols

myfittedregression = ols(formula = 'morallist ~ length + SP + GL + PvdD + PvdA + DENK + CU + CDA + SGP + VVD + PVV  ', data = bfd).fit()
print(myfittedregression.summary())

myfittedregression = ols(formula = 'harmlist ~ length + SP + GL + PvdD + PvdA + DENK + CU + CDA + SGP + VVD + PVV', data = bfd).fit()
print(myfittedregression.summary())

myfittedregression = ols(formula = 'fairnesslist ~ length + SP + GL + PvdD + PvdA + DENK + CU + CDA + SGP + VVD + PVV  ', data = bfd).fit()
print(myfittedregression.summary())

myfittedregression = ols(formula = 'ingrouplist ~ length + SP + GL + PvdD + PvdA + DENK + CU + CDA + SGP + VVD + PVV  ', data = bfd).fit()
print(myfittedregression.summary())

myfittedregression = ols(formula = 'authoritylist ~ length + SP + GL + PvdD + PvdA + DENK + CU + CDA + SGP + VVD + PVV ', data = bfd).fit()
print(myfittedregression.summary())

myfittedregression = ols(formula = 'puritylist ~ length + SP + GL + PvdD + PvdA + DENK + CU + CDA + SGP + VVD + PVV ', data = bfd).fit()
print(myfittedregression.summary())

myfittedregression = ols(formula = 'libertylist ~ length + SP + GL + PvdD + PvdA + DENK + CU + CDA + SGP + VVD + PVV ', data = bfd).fit()
print(myfittedregression.summary())

myfittedregression = ols(formula = 'moralgenlist ~ length + SP + GL + PvdD + PvdA + DENK + CU + CDA + SGP + VVD + PVV  ', data = bfd).fit()
print(myfittedregression.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              morallist   R-squared:                       0.070
# Model:                            OLS   Adj. R-squared:                  0.070
# Method:                 Least Squares   F-statistic:                     1421.
# Date:                Thu, 21 Sep 2017   Prob (F-statistic):               0.00
# Time:                        13:31:18   Log-Likelihood:            -2.0729e+05
# No. Observations:              208799   AIC:                         4.146e+05
# Df Residuals:                  208787   BIC:                         4.147e+05
# Df Model:                          11
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.
+05
# Df Model:                          11
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.0084      0.001     -7.499      0.000      -0.011      -0.006
# length         0.0005   1.22e-05     40.170      0.000       0.000       0.001
# SP             0.0090      0.002      5.935      0.000       0.006       0.012
# GL             0.0039      0.001      2.723      0.006       0.001       0.007
# PvdD          -0.0007      0.002     -0.410      0.682      -0.004       0.003
# PvdA           0.0024      0.002      1.470      0.141      -0.001       0.006
# DENK          -0.0091      0.003     -3.540      0.000      -0.014      -0.004
# CU             0.0058      0.002      2.879      0.004       0.002       0.010
# CDA            0.0011      0.001      0.821      0.412      -0.001       0.004
# SGP           -0.0043      0.002     -1.826      0.068      -0.009       0.000
# VVD            0.0053      0.001      4.807      0.000       0.003       0.007
# PVV           -0.0024      0.001     -1.814      0.070      -0.005       0.000
# ==============================================================================
# Omnibus:                   275530.136   Durbin-Watson:                   1.878
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):         42911224.158
# Skew:                           7.712   Prob(JB):                         0.00
# Kurtosis:                      71.516   Cond. No.                         610.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           moralgenlist   R-squared:                       0.007
# Model:                            OLS   Adj. R-squared:                  0.007
# Method:                 Least Squares   F-statistic:                     141.6
# Date:                Thu, 21 Sep 2017   Prob (F-statistic):               0.00
# Time:                        13:31:22   Log-Likelihood:                 10599.
# No. Observations:              208799   AIC:                        -2.117e+04
# Df Residuals:                  208787   BIC:                        -2.105e+04
# Df Model:                          11
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.0063      0.002     -3.823      0.000      -0.010      -0.003
# length         0.0007   1.79e-05     38.516      0.000       0.001       0.001
# SP             0.0112      0.002      5.052      0.000       0.007       0.016
# GL             0.0157      0.002      7.546      0.000       0.012       0.020
# PvdD           0.0105      0.003      3.927      0.000       0.005       0.016
# PvdA           0.0074      0.002      3.139      0.002       0.003       0.012
# DENK           0.0051      0.004      1.342      0.180      -0.002       0.012
# CU             0.0068      0.003      2.311      0.021       0.001       0.013
# CDA            0.0052      0.002      2.748      0.006       0.001       0.009
# SGP            0.0017      0.003      0.491      0.624      -0.005       0.008
# VVD            0.0084      0.002      5.231      0.000       0.005       0.012
# PVV           -0.0009      0.002     -0.485      0.628      -0.005       0.003
# ==============================================================================
# Omnibus:                   254606.336   Durbin-Watson:                   1.913
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):         28563278.010
# Skew:                           6.777   Prob(JB):                         0.00
# Kurtosis:                      58.673   Cond. No.                         610.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
bfd['moralratio'] = bfd['morallist']/bfd['length']
bfd['harmratio'] = bfd['harmlist']/bfd['length']
bfd['fairnessratio'] = bfd['fairnesslist']/bfd['length']
bfd['ingroupratio'] = bfd['ingrouplist']/bfd['length']
bfd['authorityratio'] = bfd['authoritylist']/bfd['length']
bfd['purityratio'] = bfd['puritylist']/bfd['length']
bfd['libertyratio'] = bfd['libertylist']/bfd['length']
bfd['moralgenratio'] = bfd['moralgenlist']/bfd['length']

# %%
myfittedregression = ols(formula = 'moralratio ~ SP + GL + PvdD + PvdA + DENK + CU + CDA + SGP + VVD + PVV  ', data = bfd).fit()
print(myfittedregression.summary())

myfittedregression = ols(formula = 'harmratio ~ SP + GL + PvdD + PvdA + DENK + CU + CDA + SGP + VVD + PVV  ', data = bfd).fit()
print(myfittedregression.summary())

myfittedregression = ols(formula = 'fairnessratio ~ SP + GL + PvdD + PvdA + DENK + CU + CDA + SGP + VVD + PVV   ', data = bfd).fit()
print(myfittedregression.summary())

myfittedregression = ols(formula = 'ingroupratio ~ SP + GL + PvdD + PvdA + DENK + CU + CDA + SGP + VVD + PVV  ', data = bfd).fit()
print(myfittedregression.summary())

myfittedregression = ols(formula = 'authorityratio ~ SP + GL + PvdD + PvdA + DENK + CU + CDA + SGP + VVD + PVV   ', data = bfd).fit()
print(myfittedregression.summary())

myfittedregression = ols(formula = 'purityratio ~   SP + GL + PvdD + PvdA + DENK + CU + CDA + SGP + VVD + PVV  ', data = bfd).fit()
print(myfittedregression.summary())

myfittedregression = ols(formula = 'libertyratio ~   SP + GL + PvdD + PvdA + DENK + CU + CDA + SGP + VVD + PVV   ', data = bfd).fit()
print(myfittedregression.summary())

myfittedregression = ols(formula = 'moralgenratio ~   SP + GL + PvdD + PvdA + DENK + CU + CDA + SGP + VVD + PVV  ', data = bfd).fit()
print(myfittedregression.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             moralratio   R-squared:                       0.002
# Model:                            OLS   Adj. R-squared:                  0.002
# Method:                 Least Squares   F-statistic:                     38.92
# Date:                Thu, 21 Sep 2017   Prob (F-statistic):           2.17e-77
# Time:                        13:31:24   Log-Likelihood:             6.0642e+05
# No. Observations:              208595   AIC:                        -1.213e+06
# Df Residuals:                  208584   BIC:                        -1.213e+06
# Df Model:                          10
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.
# Date:                Thu, 21 Sep 2017   Prob (F-statistic):           1.51e-17
# Time:                        13:31:27   Log-Likelihood:             9.3024e+05
# No. Observations:              208595   AIC:                        -1.860e+06
# Df Residuals:                  208584   BIC:                        -1.860e+06
# Df Model:                          10
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.0003    1.5e-05     20.645      0.000       0.000       0.000
# SP             0.0002    2.7e-05      6.126      0.000       0.000       0.000
# GL          3.669e-05   2.53e-05      1.450      0.147   -1.29e-05    8.63e-05
# PvdD       -1.801e-05   3.26e-05     -0.553      0.580   -8.19e-05    4.59e-05
# PvdA        3.585e-06   2.88e-05      0.125      0.901   -5.28e-05       6e-05
# DENK          -0.0001    4.6e-05     -2.343      0.019      -0.000   -1.76e-05
# CU             0.0001   3.59e-05      3.163      0.002    4.31e-05       0.000
# CDA         1.456e-05   2.29e-05      0.635      0.526   -3.04e-05    5.95e-05
# SGP        -9.666e-05   4.18e-05     -2.311      0.021      -0.000   -1.47e-05
# VVD         8.573e-05   1.96e-05      4.377      0.000    4.73e-05       0.000
# PVV        -2.929e-05   2.33e-05     -1.259      0.208   -7.49e-05    1.63e-05
# ==============================================================================
# Omnibus:                   382323.518   Durbin-Watson:                   1.862
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):        954776695.199
# Skew:                          13.504   Prob(JB):                         0.00
# Kurtosis:                     333.337   Cond. No.                         9.94
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          moralgenratio   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                  0.000
# Method:                 Least Squares   F-statistic:                     7.068
# Date:                Thu, 21 Sep 2017   Prob (F-statistic):           3.30e-11
# Time:                        13:31:27   Log-Likelihood:             8.1076e+05
# No. Observations:              208595   AIC:                        -1.621e+06
# Df Residuals:                  208584   BIC:                        -1.621e+06
# Df Model:                          10
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.0006   2.66e-05     22.423      0.000       0.001       0.001
# SP             0.0002   4.79e-05      3.647      0.000    8.07e-05       0.000
# GL             0.0003   4.49e-05      6.702      0.000       0.000       0.000
# PvdD           0.0001   5.78e-05      2.465      0.014    2.92e-05       0.000
# PvdA           0.0001    5.1e-05      2.010      0.044    2.53e-06       0.000
# DENK        7.738e-05   8.16e-05      0.948      0.343   -8.26e-05       0.000
# CU          7.327e-05   6.36e-05      1.153      0.249   -5.13e-05       0.000
# CDA         4.556e-05   4.07e-05      1.120      0.263   -3.42e-05       0.000
# SGP         7.399e-05   7.42e-05      0.998      0.318   -7.14e-05       0.000
# VVD            0.0001   3.47e-05      3.482      0.000    5.29e-05       0.000
# PVV        -3.364e-05   4.12e-05     -0.816      0.415      -0.000    4.72e-05
# ==============================================================================
# Omnibus:                   425457.208   Durbin-Watson:                   1.924
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):       2689609395.743
# Skew:                          16.865   Prob(JB):                         0.00
# Kurtosis:                     558.263   Cond. No.                         9.94
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
bfd['moraldummy'] = np.where(bfd['morallist']>0, '1', '0')
bfd['harmdummy'] = np.where(bfd['harmlist']>0, '1', '0')
bfd['fairnessdummy'] = np.where(bfd['fairnesslist']>0, '1', '0')
bfd['ingroupdummy'] = np.where(bfd['ingrouplist']>0, '1', '0')
bfd['authoritydummy'] = np.where(bfd['authoritylist']>0, '1', '0')
bfd['puritydummy'] = np.where(bfd['puritylist']>0, '1', '0')
bfd['libertydummy'] = np.where(bfd['libertylist']>0, '1', '0')
bfd['moralgendummy'] = np.where(bfd['moralgenlist']>0, '1', '0')

# %%
bfd.to_csv('/home/linda/manifestos/combined data/Dutch tweets.csv')
bfd.to_csv('/home/linda/myrealcomputer/Dutch tweets.csv')
