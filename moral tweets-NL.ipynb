# %%
import nltk
nltk.download()

from nltk.stem.snowball import SnowballStemmer
stemmer=SnowballStemmer("dutch")

from nltk.corpus import stopwords
stopwords_ned = stopwords.words('dutch')
stopwords_eng = stopwords.words('english')
stopwords = stopwords_eng + stopwords_ned

import re

moraldic = open("/home/linda/manifestos/manifestos/mf/dutch moral foundations dictionary ext.1.dic").read().replace("\t", "").replace("\s", "")


harmvirtue_ned = re.findall('([a-z]+\*?).*[0][1]', moraldic)
harmvice_ned = re.findall('([a-z]+\*?).*[0][2]', moraldic)
fairnessvirtue_ned = re.findall('([a-z]+\*?).*[0][3]', moraldic)
fairnessvice_ned = re.findall('([a-z]+\*?).*[0][4]', moraldic)
ingroupvirtue_ned = re.findall('([a-z]+\*?).*[0][5]', moraldic)
ingroupvice_ned = re.findall('([a-z]+\*?).*[0][6]', moraldic)
authorityvirtue_ned = re.findall('([a-z]+\*?).*[0][7]', moraldic)
authorityvice_ned = re.findall('([a-z]+\*?).*[0][8]', moraldic)
purityvirtue_ned = re.findall('([a-z]+\*?).*[0][9]', moraldic)
purityvice_ned = re.findall('([a-z]+\*?).*[1][0]', moraldic)
moralitygeneral_ned = re.findall('([a-z]+\*?).*[1][1]', moraldic)
libertyvirtue_ned = re.findall('([a-z]+\*?).*[1][2]', moraldic)
libertyvice_ned = re.findall('([a-z]+\*?).*[1][3]', moraldic)


moralityall_ned = re.findall('([a-z]+\*?).*[01-11]', moraldic)
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml

# %%
moraldic_eng = open("/home/linda/manifestos/manifestos/mf/moral foundations dictionary ext.1.dic").read().replace("\t", "").replace("\s", "")


harmvirtue_eng = re.findall('([a-z]+\*?).*[0][1]', moraldic_eng)
harmvice_eng = re.findall('([a-z]+\*?).*[0][2]', moraldic_eng)
fairnessvirtue_eng = re.findall('([a-z]+\*?).*[0][3]', moraldic_eng)
fairnessvice_eng = re.findall('([a-z]+\*?).*[0][4]', moraldic_eng)
ingroupvirtue_eng = re.findall('([a-z]+\*?).*[0][5]', moraldic)
ingroupvice_eng = re.findall('([a-z]+\*?).*[0][6]', moraldic_eng)
authorityvirtue_eng = re.findall('([a-z]+\*?).*[0][7]', moraldic_eng)
authorityvice_eng = re.findall('([a-z]+\*?).*[0][8]', moraldic_eng)
purityvirtue_eng = re.findall('([a-z]+\*?).*[0][9]', moraldic_eng)
purityvice_eng = re.findall('([a-z]+\*?).*[1][0]', moraldic_eng)
moralitygeneral_eng = re.findall('([a-z]+\*?).*[1][1]', moraldic_eng)
libertyvirtue_eng = re.findall('([a-z]+\*?).*[1][2]', moraldic_eng)
libertyvice_eng = re.findall('([a-z]+\*?).*[1][3]', moraldic_eng)


moralityall_eng = re.findall('([a-z]+\*?).*[01-11]', moraldic_eng)

# %%
print(libertyvirtue_eng)
# Out:
# ['individual', 'individualit*', 'freedom', 'liberty', 'develop*', 'independen*', 'autonom*', 'independen*', 'self', 'identity']

# %%
harmvirtue = harmvirtue_eng + harmvirtue_ned
harmvice = harmvice_eng + harmvice_ned
fairnessvirtue = fairnessvirtue_eng + fairnessvirtue_ned
fairnessvice = fairnessvice_eng + fairnessvice_ned
ingroupvirtue = ingroupvirtue_eng + ingroupvirtue_ned
ingroupvice = ingroupvice_eng + ingroupvice_ned
authorityvirtue = authorityvirtue_eng + authorityvirtue_ned
authorityvice = authorityvice_eng + authorityvice_ned
purityvirtue = purityvirtue_eng + purityvirtue_ned
purityvice = purityvice_eng + purityvice_ned
libertyvirtue = libertyvirtue_eng + libertyvirtue_ned
libertyvice = libertyvice_eng + libertyvice_ned
moralitygeneral = moralitygeneral_eng + moralitygeneral_ned
moralityall = moralityall_eng + moralityall_ned

# %%
import csv
from glob import glob
import re
from itertools import islice
import string

names=[]
parties=[]
lidmaatschap = {}

alltweets = glob("/home/linda/manifestos/tweets/downloads/NL/*.csv")
peeps = [p.split('/')[-1].strip('.csv.') for p in alltweets]

names = [pp.split('_')[-3].strip() for pp in peeps]
parties = [pp.split('_')[-2].strip() for pp in peeps]

lidmaatschap = dict(zip(names,parties))
filenames = dict(zip(names, alltweets))

print(names)
# Out:
# ['PVV', 'JoelVoordewind', 'RidderDionGraus', 'GraafdeMachiel', 'gjfpopken', 'HenkKrol', 'LammertvanRaan', 'AnneKuik', 'gertjansegers', 'ZelYassini', 'Martijncda', 'DilanYesilgoz', 'rvanaalst', 'thierrybaudet', 'SandraBeckerman', 'ZihniOzdil', 'bartvankent', 'KopsPVV', 'HalbeZijlstra', 'bvantwout', 'SvVeldhoven', 'bartsnels', 'FrankFutselaar', 'RaymondKnops', 'ChrisvanDamCDA', 'pvv', 'BisschopRoelof', 'foortvanoosten', 'Middendorp', 'piadijkstra', 'LodewijkA', 'dijkvangijs', 'CorinneEllemeet', 'attjekuiken', 'harmbeertema', 'keesvdstaaij', 'arladikfaber', 'kirstenvdhul', 'SalimaBelhaj', 'KarenGerbrands1', 'mariannethieme', 'AntjeDiertens', 'JaspervanDijkSP', 'dijksma', 'tamaravanark', 'mulder', 'JessicaVanEijs', 'SvenKoopmansVVD', 'FleurAgemaPVV', 'VickyMaeijer', 'leondejong', 'KeesVee', 'TjeerdD66', 'MvanToorenburg', 'MustafaAmhaouch', 'erikziengs', 'MonaKeijzer', 'HanTenBroeke', 'GL', 'dijkhoff', 'RenePetersOss', 'ivanengelshoven', 'RoaldLinde', 'WassenbergFrank', 'DennisWiersma', 'wsjoerdsma', 'MarijnissenL', 'wkoolmees', 'JeanineHennis', 'jesseklaver', 'HankeBruinsSlot', 'markharbers', 'rikgrashoff', 'AgnesMulderCDA', 'CemLacin', 'kathalijne', 'GidiMarkuszower', 'remcovvd', 'BarbaraVVD', 'danielkoerhuis', 'Dijsselbloem', 'MvRooijen', 'ArneWeverling', 'Lisawesterveld', 'RenskeLeijten', 'JacoGeurts', 'harryvdmolen', 'ybrandbuma', 'Thiddema', 'edgarmulder1', 'TomvanderLee', 'andrebosman', 'RobJetten', 'ockjetellegen', 'elcukozturknl', 'khadijaArib', 'azarkan', 'geertwilderspvv', 'Hermans', 'markrutte', 'mvonmartels', 'SadetKarabulut', 'estherouwehand', 'arolaschouten', 'MinPres', 'Meenen', 'APechtold', 'anweyenberg', 'jpaternotte', 'elbertdijkgraaf', 'henknijboer', 'RaymondRoonPVV', 'bentebecker', 'CvanBrenk', 'tunahankuzu', 'lindavoortman', 'RensRaemakers', 'BramvanOjikGL', 'PieterHeerma', 'Worsdorfer', 'MalikAzmani', 'michelrog', 'LeonieSazias', 'emileroemer', 'GroenLiesbeth', 'aukjedevries', 'lilianhelderpvv', 'PieterOmtzigt', 'GroothuizenD66', 'NevinOzutok', 'nijkerken', 'ErikRonnes', 'Bergkamp', 'peterkwint', 'MaartenHijink', 'arnorutte', 'eppobruins', 'achrafboualid66', 'SanderDekker', 'JobaCDA', 'FemkeMerel', 'HelmaLodders', 'NineKooiman', 'IsabelleDiks']

# %%
import csv
from glob import glob
import re
from itertools import islice
import string

names=[]
parties=[]
lidmaatschap = {}




alltweets = glob("/home/linda/manifestos/tweets/downloads/NL/*.csv")
peeps = [p.split('/')[-1].strip('.csv.') for p in alltweets]

names = [pp.split('_')[-3].strip() for pp in peeps]
parties = [pp.split('_')[-2].strip() for pp in peeps]

lidmaatschap = dict(zip(names,parties))
filenames = dict(zip(names, alltweets))


for name in names[99:]:
    ids=[]
    favourites=[]
    retweets=[]
    dates=[]
    quote=[]
    rt=[]
    text=[]
    file = filenames[name]
    print("now opening", file)
    with open(file) as fi:
        reader = csv.reader(fi,delimiter=',')
        for row in csv.reader(islice(fi, None)):
            ids.append(row[0])
            favourites.append(row[1])
            retweets.append(row[2])
            dates.append(row[3])
            quote.append(row[4])
            rt.append(row[5])
            text.append(row[6]) 
        translate_table = dict((ord(char), None) for char in string.punctuation)   
        text = [t.translate(translate_table) for t in text]
        text = [t.lower() for t in text]
        text = [t.strip() for t in text if t.strip()!=""]
        text = [t.strip() for t in text if len(t)> 10]
        text = [' '.join(w for w in t.split() if w.lower() not in stopwords) for t in text]
        morallist=[]
        harmvirtuelist = []
        harmvicelist = []
        fairnessvirtuelist = []
        fairnessvicelist = []
        ingroupvirtuelist = []
        ingroupvicelist = []
        authorityvirtuelist = []
        authorityvicelist = []
        purityvirtuelist = []
        purityvicelist = []
        moralgenlist = []
        libertyvirtuelist = []
        libertyvicelist = []
        harmlist = []
        fairnesslist = []
        ingrouplist = []
        authoritylist = []
        puritylist = []
        libertylist=[]
        length=[]
        for line in text:
            moralcount=0
            harmvirtuecount=0
            harmvicecount=0
            fairnessvirtuecount=0
            fairnessvicecount=0
            ingroupvirtuecount=0
            ingroupvicecount=0
            authorityvirtuecount=0
            authorityvicecount=0
            purityvirtuecount=0
            purityvicecount=0
            libertyvirtuecount=0
            libertyvicecount=0
            moralgencount=0
            for pattern in moralityall:
                for word in line.split():
                    if pattern[-1] == '*' and word.startswith(pattern[:-1]) or word == pattern:
                        moralcount+=1
            for pattern in harmvirtue:
                for word in line.split():
                    if pattern[-1] == '*' and word.startswith(pattern[:-1]) or word == pattern:
                        harmvirtuecount+=1
            for pattern in harmvice:
                for word in line.split():
                    if pattern[-1] == '*' and word.startswith(pattern[:-1]) or word == pattern:
                        harmvicecount+=1
            for pattern in fairnessvirtue:
                for word in line.split():
                    if pattern[-1] == '*' and word.startswith(pattern[:-1]) or word == pattern:
                        fairnessvirtuecount+=1
            for pattern in fairnessvice:
                for word in line.split():
                    if pattern[-1] == '*' and word.startswith(pattern[:-1]) or word == pattern:
                        fairnessvicecount+=1
            for pattern in ingroupvirtue:
                for word in line.split():
                    if pattern[-1] == '*' and word.startswith(pattern[:-1]) or word == pattern:
                        ingroupvirtuecount+=1
            for pattern in ingroupvice:
                for word in line.split():
                    if pattern[-1] == '*' and word.startswith(pattern[:-1]) or word == pattern:
                        ingroupvicecount+=1
            for pattern in authorityvirtue:
                for word in line.split():
                    if pattern[-1] == '*' and word.startswith(pattern[:-1]) or word == pattern:
                        authorityvirtuecount+=1
            for pattern in authorityvice:
                for word in line.split():
                    if pattern[-1] == '*' and word.startswith(pattern[:-1]) or word == pattern:
                        authorityvicecount+=1
            for pattern in purityvirtue:
                for word in line.split():
                    if pattern[-1] == '*' and word.startswith(pattern[:-1]) or word == pattern:
                        purityvirtuecount+=1
            for pattern in purityvice:
                for word in line.split():
                    if pattern[-1] == '*' and word.startswith(pattern[:-1]) or word == pattern:
                        purityvicecount+=1        
            for pattern in libertyvirtue:
                for word in line.split():
                    if pattern[-1] == '*' and word.startswith(pattern[:-1]) or word == pattern:
                        libertyvirtuecount+=1
            for pattern in libertyvice:
                for word in line.split():
                    if pattern[-1] == '*' and word.startswith(pattern[:-1]) or word == pattern:
                        libertyvicecount+=1
            for pattern in moralitygeneral:
                for word in line.split():
                    if pattern[-1] == '*' and word.startswith(pattern[:-1]) or word == pattern:
                        moralgencount+=1
            morallist.append(moralcount)
            harmvirtuelist.append(harmvirtuecount)
            harmvicelist.append(harmvicecount)
            harmlist.append(harmvicecount+harmvirtuecount)
            fairnessvirtuelist.append(fairnessvirtuecount)
            fairnessvicelist.append(fairnessvicecount)
            fairnesslist.append(fairnessvicecount+fairnessvirtuecount)
            ingroupvirtuelist.append(ingroupvirtuecount)
            ingroupvicelist.append(ingroupvicecount)
            ingrouplist.append(ingroupvirtuecount + ingroupvicecount)
            authorityvirtuelist.append(authorityvirtuecount)
            authorityvicelist.append(authorityvicecount)
            authoritylist.append(authorityvicecount + authorityvirtuecount)
            purityvirtuelist.append(purityvirtuecount)
            purityvicelist.append(purityvicecount)
            puritylist.append(purityvicecount + purityvirtuecount)
            libertyvirtuelist.append(libertyvirtuecount)
            libertyvicelist.append(libertyvicecount)
            libertylist.append(libertyvicecount + libertyvirtuecount)
            moralgenlist.append(moralgencount)
            length.append(len(line))
        output = zip(ids,text,dates, favourites, retweets, quote, rt, morallist, harmvirtuelist, harmvicelist, harmlist, fairnessvirtuelist, fairnessvicelist, fairnesslist, ingroupvirtuelist, ingroupvicelist, ingrouplist, purityvirtuelist, purityvicelist, puritylist, authorityvirtuelist, authorityvicelist, authoritylist, libertyvirtuelist, libertyvicelist, libertylist, moralgenlist, length)
        outputfile = "/home/linda/manifestos/tweets/downloads/NL/coded/{}_{}_coded.csv".format(name,lidmaatschap[name])
        print("Writing stuff to {}".format(outputfile))
        with open(outputfile, "w") as fo:
            writer=csv.writer(fo)
            writer.writerows(output)
# Out:
# now opening /home/linda/manifestos/tweets/downloads/NL/markrutte_VVD_tweets.csv
# Writing stuff to /home/linda/manifestos/tweets/downloads/NL/coded/markrutte_VVD_coded.csv
# now opening /home/linda/manifestos/tweets/downloads/NL/mvonmartels_CDA_tweets.csv
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-32-a3e8894d0e09> in <module>()
#      86             for pattern in moralityall:
#      87                 for word in line.split():
# ---> 88                     if pattern[-1] == '*' and word.startswith(pattern[:-1]) or word == pattern:
#      89                         moralcount+=1
#      90             for pattern in harmvirtue:
#
# KeyboardInterrupt:

# %%
import glob
import pandas as pd
import numpy as np
import re
import os

path = "/home/linda/manifestos/tweets/downloads/NL/coded/"
allfiles = glob.glob(os.path.join(path,"*.csv"))

peeps = [p.split('/')[-1].strip('.csv.') for p in alltweets]

names = [pp.split('_')[-3].strip() for pp in peeps]
parties = [pp.split('_')[-2].strip() for pp in peeps]

lidmaatschap = dict(zip(names,parties))
namefile = dict(zip(names,allfiles))

# %%
print(lidmaatschap)
print(namefile)
# Out:
# {'ArneWeverling': 'VVD', 'SalimaBelhaj': 'D66', 'MonaKeijzer': 'CDA', 'KeesVee': 'D66', 'CvanBrenk': '50PLUS', 'wsjoerdsma': 'D66', 'MvRooijen': '50PLUS', 'RenePetersOss': 'CDA', 'HenkKrol': '50PLUS', 'jpaternotte': 'D66', 'gertjansegers': 'CU', 'WassenbergFrank': 'PvdD', 'RobJetten': 'D66', 'keesvdstaaij': 'SGP', 'MinPres': 'VVD', 'elbertdijkgraaf': 'SGP', 'harmbeertema': 'PVV', 'MalikAzmani': 'VVD', 'VickyMaeijer': 'PVV', 'mariannethieme': 'PvdD', 'thierrybaudet': 'FvD', 'RensRaemakers': 'D66', 'LodewijkA': 'PvdA', 'MaartenHijink': 'SP', 'GroothuizenD66': 'D66', 'FleurAgemaPVV': 'PVV', 'MustafaAmhaouch': 'CDA', 'FrankFutselaar': 'SP', 'aukjedevries': 'VVD', 'markrutte': 'VVD', 'dijkhoff': 'VVD', 'GroenLiesbeth': 'GL', 'henknijboer': 'PvdA', 'lilianhelderpvv': 'PVV', 'ZelYassini': 'VVD', 'anweyenberg': 'D66', 'SadetKarabulut': 'SP', 'PVV': 'PVV', 'LammertvanRaan': 'PvdD', 'CemLacin': 'SP', 'mulder': 'VVD', 'Worsdorfer': 'VVD', 'HelmaLodders': 'VVD', 'RaymondRoonPVV': 'PVV', 'DilanYesilgoz': 'VVD', 'RidderDionGraus': 'PVV', 'bartvankent': 'SP', 'ybrandbuma': 'CDA', 'Bergkamp': 'D66', 'lindavoortman': 'GL', 'ChrisvanDamCDA': 'CDA', 'SvenKoopmansVVD': 'VVD', 'mvonmartels': 'CDA', 'dijksma': 'PvdA', 'harryvdmolen': 'CDA', 'JessicaVanEijs': 'D66', 'LeonieSazias': '50PLUS', 'piadijkstra': 'D66', 'RaymondKnops': 'CDA', 'JaspervanDijkSP': 'SP', 'ErikRonnes': 'CDA', 'attjekuiken': 'PvdA', 'FemkeMerel': 'PvdD', 'estherouwehand': 'PvdD', 'tunahankuzu': 'DENK', 'BramvanOjikGL': 'GL', 'PieterOmtzigt': 'CDA', 'emileroemer': 'SP', 'dijkvangijs': 'PvdA', 'Thiddema': 'FvD', 'khadijaArib': 'PvdA', 'Dijsselbloem': 'PvdA', 'AnneKuik': 'CDA', 'NineKooiman': 'SP', 'CorinneEllemeet': 'GL', 'GL': 'GL', 'Meenen': 'D66', 'DennisWiersma': 'VVD', 'APechtold': 'D66', 'bvantwout': 'VVD', 'eppobruins': 'CU', 'andrebosman': 'VVD', 'KarenGerbrands1': 'PVV', 'edgarmulder1': 'PVV', 'erikziengs': 'VVD', 'geertwilderspvv': 'PVV', 'michelrog': 'CDA', 'AgnesMulderCDA': 'CDA', 'bartsnels': 'GL', 'Middendorp': 'VVD', 'leondejong': 'PVV', 'KopsPVV': 'PVV', 'tamaravanark': 'VVD', 'SanderDekker': 'VVD', 'GidiMarkuszower': 'PVV', 'RenskeLeijten': 'SP', 'ZihniOzdil': 'GL', 'pvv': 'PVV', 'azarkan': 'DENK', 'gjfpopken': 'PVV', 'markharbers': 'VVD', 'IsabelleDiks': 'GL', 'arolaschouten': 'CU', 'Lisawesterveld': 'GL', 'HalbeZijlstra': 'VVD', 'SvVeldhoven': 'D66', 'MarijnissenL': 'SP', 'kathalijne': 'GL', 'foortvanoosten': 'VVD', 'bentebecker': 'VVD', 'Martijncda': 'CDA', 'wkoolmees': 'D66', 'NevinOzutok': 'GL', 'HankeBruinsSlot': 'CDA', 'arnorutte': 'VVD', 'elcukozturknl': 'DENK', 'AntjeDiertens': 'D66', 'ockjetellegen': 'VVD', 'GraafdeMachiel': 'PVV', 'PieterHeerma': 'CDA', 'RoaldLinde': 'VVD', 'rikgrashoff': 'GL', 'achrafboualid66': 'D66', 'nijkerken': 'VVD', 'TjeerdD66': 'D66', 'JobaCDA': 'CDA', 'kirstenvdhul': 'PvdA', 'SandraBeckerman': 'SP', 'JacoGeurts': 'CDA', 'jesseklaver': 'GL', 'HanTenBroeke': 'VVD', 'JoelVoordewind': 'CU', 'MvanToorenburg': 'CDA', 'Hermans': 'VVD', 'JeanineHennis': 'VVD', 'arladikfaber': 'CU', 'peterkwint': 'SP', 'remcovvd': 'VVD', 'BarbaraVVD': 'VVD', 'BisschopRoelof': 'SGP', 'danielkoerhuis': 'VVD', 'rvanaalst': 'PVV', 'ivanengelshoven': 'D66', 'TomvanderLee': 'GL'}
# {'ArneWeverling': '/home/linda/manifestos/tweets/downloads/NL/coded/gjfpopken_PVV_coded.csv', 'SalimaBelhaj': '/home/linda/manifestos/tweets/downloads/NL/coded/AnneKuik_CDA_coded.csv', 'MonaKeijzer': '/home/linda/manifestos/tweets/downloads/NL/coded/ErikRonnes_CDA_coded.csv', 'KeesVee': '/home/linda/manifestos/tweets/downloads/NL/coded/ChrisvanDamCDA_CDA_coded.csv', 'CvanBrenk': '/home/linda/manifestos/tweets/downloads/NL/coded/harmbeertema_PVV_coded.csv', 'wsjoerdsma': '/home/linda/manifestos/tweets/downloads/NL/coded/MaartenHijink_SP_coded.csv', 'MvRooijen': '/home/linda/manifestos/tweets/downloads/NL/coded/Martijncda_CDA_coded.csv', 'RenePetersOss': '/home/linda/manifestos/tweets/downloads/NL/coded/RobJetten_D66_coded.csv', 'HenkKrol': '/home/linda/manifestos/tweets/downloads/NL/coded/mulder_VVD_coded.csv', 'jpaternotte': '/home/linda/manifestos/tweets/downloads/NL/coded/wkoolmees_D66_coded.csv', 'gertjansegers': '/home/linda/manifestos/tweets/downloads/NL/coded/lilianhelderpvv_PVV_coded.csv', 'WassenbergFrank': '/home/linda/manifestos/tweets/downloads/NL/coded/JoelVoordewind_CU_coded.csv', 'RobJetten': '/home/linda/manifestos/tweets/downloads/NL/coded/piadijkstra_D66_coded.csv', 'keesvdstaaij': '/home/linda/manifestos/tweets/downloads/NL/coded/MvRooijen_50PLUS_coded.csv', 'MinPres': '/home/linda/manifestos/tweets/downloads/NL/coded/RenePetersOss_CDA_coded.csv', 'elbertdijkgraaf': '/home/linda/manifestos/tweets/downloads/NL/coded/BramvanOjikGL_GL_coded.csv', 'harmbeertema': '/home/linda/manifestos/tweets/downloads/NL/coded/bvantwout_VVD_coded.csv', 'MalikAzmani': '/home/linda/manifestos/tweets/downloads/NL/coded/khadijaArib_PvdA_coded.csv', 'VickyMaeijer': '/home/linda/manifestos/tweets/downloads/NL/coded/RensRaemakers_D66_coded.csv', 'mariannethieme': '/home/linda/manifestos/tweets/downloads/NL/coded/erikziengs_VVD_coded.csv', 'thierrybaudet': '/home/linda/manifestos/tweets/downloads/NL/coded/JessicaVanEijs_D66_coded.csv', 'RensRaemakers': '/home/linda/manifestos/tweets/downloads/NL/coded/ArneWeverling_VVD_coded.csv', 'LodewijkA': '/home/linda/manifestos/tweets/downloads/NL/coded/Thiddema_FvD_coded.csv', 'MaartenHijink': '/home/linda/manifestos/tweets/downloads/NL/coded/NevinOzutok_GL_coded.csv', 'GroothuizenD66': '/home/linda/manifestos/tweets/downloads/NL/coded/Hermans_VVD_coded.csv', 'FleurAgemaPVV': '/home/linda/manifestos/tweets/downloads/NL/coded/HalbeZijlstra_VVD_coded.csv', 'MustafaAmhaouch': '/home/linda/manifestos/tweets/downloads/NL/coded/Worsdorfer_VVD_coded.csv', 'FrankFutselaar': '/home/linda/manifestos/tweets/downloads/NL/coded/RoaldLinde_VVD_coded.csv', 'aukjedevries': '/home/linda/manifestos/tweets/downloads/NL/coded/elbertdijkgraaf_SGP_coded.csv', 'markrutte': '/home/linda/manifestos/tweets/downloads/NL/coded/HanTenBroeke_VVD_coded.csv', 'dijkhoff': '/home/linda/manifestos/tweets/downloads/NL/coded/nijkerken_VVD_coded.csv', 'GroenLiesbeth': '/home/linda/manifestos/tweets/downloads/NL/coded/HankeBruinsSlot_CDA_coded.csv', 'henknijboer': '/home/linda/manifestos/tweets/downloads/NL/coded/ZelYassini_VVD_coded.csv', 'lilianhelderpvv': '/home/linda/manifestos/tweets/downloads/NL/coded/andrebosman_VVD_coded.csv', 'ZelYassini': '/home/linda/manifestos/tweets/downloads/NL/coded/CemLacin_SP_coded.csv', 'anweyenberg': '/home/linda/manifestos/tweets/downloads/NL/coded/leondejong_PVV_coded.csv', 'SadetKarabulut': '/home/linda/manifestos/tweets/downloads/NL/coded/eppobruins_CU_coded.csv', 'PVV': '/home/linda/manifestos/tweets/downloads/NL/coded/MvanToorenburg_CDA_coded.csv', 'LammertvanRaan': '/home/linda/manifestos/tweets/downloads/NL/coded/MonaKeijzer_CDA_coded.csv', 'CemLacin': '/home/linda/manifestos/tweets/downloads/NL/coded/bentebecker_VVD_coded.csv', 'mulder': '/home/linda/manifestos/tweets/downloads/NL/coded/WassenbergFrank_PvdD_coded.csv', 'Worsdorfer': '/home/linda/manifestos/tweets/downloads/NL/coded/ybrandbuma_CDA_coded.csv', 'HelmaLodders': '/home/linda/manifestos/tweets/downloads/NL/coded/elcukozturknl_DE ...

# %%
np_array_list = []
data = []
for name in names:
    file_= namefile[name]
    df = pd.read_csv(file_,index_col=None, header=0)
    df['politicians'] = name
    df['party'] = lidmaatschap[name]
    data.append(df)
    np_array_list.append(df.as_matrix())

comb_np_array = np.vstack(np_array_list)
big_frame = pd.DataFrame(comb_np_array)

big_frame.columns = ['id','tweet','date', 'likes', 'retweets', 'quote', 'rt', 'morallist', 'harmvirtuelist', 'harmvicelist', 'harmlist', 'fairnessvirtuelist', 'fairnessvicelist',  'fairnesslist', 'ingroupvirtuelist', 'ingroupvicelist', 'ingrouplist', 'purityvirtuelist', 'purityvicelist', 'puritylist', 'authorityvirtuelist', 'authorityvicelist', 'authoritylist', 'libertyvirtuelist', 'libertyvicelist', 'libertylist', 'moralgenlist', 'length', 'name', 'party']

bf = big_frame.fillna(value = 0)

# %%
parties = pd.get_dummies(bf['party'])

bfd = pd.concat([bf, parties], axis=1)

# %%
for foundation in ['harmlist','puritylist','ingrouplist','authoritylist', 'fairnesslist', 'libertylist','moralgenlist',  'morallist']:
    print(foundation.upper())
    print(bfd[foundation].value_counts(sort=True, normalize=True))
    print('-------------------------------------------\n')
# Out:
# HARMLIST
# 0    0.894826
# 1    0.091913
# 2    0.011598
# 3    0.001448
# 4    0.000200
# 5    0.000011
# 6    0.000003
# Name: harmlist, dtype: float64
# -------------------------------------------
#
# PURITYLIST
# 0    0.975383
# 1    0.022988
# 2    0.001471
# 3    0.000146
# 4    0.000011
# Name: puritylist, dtype: float64
# -------------------------------------------
#
# INGROUPLIST
# 0    0.946430
# 2    0.042591
# 1    0.008236
# 4    0.002128
# 3    0.000520
# 6    0.000069
# 5    0.000017
# 8    0.000009
# Name: ingrouplist, dtype: float64
# -------------------------------------------
#
# AUTHORITYLIST
# 0    0.933420
# 1    0.057695
# 2    0.008056
# 3    0.000560
# 4    0.000246
# 5    0.000014
# 6    0.000006
# 7    0.000003
# Name: authoritylist, dtype: float64
# -------------------------------------------
#
# FAIRNESSLIST
# 0    0.966442
# 1    0.027665
# 2    0.005076
# 3    0.000651
# 4    0.000131
# 5    0.000020
# 6    0.000014
# Name: fairnesslist, dtype: float64
# -------------------------------------------
#
# LIBERTYLIST
# 0    0.978691
# 1    0.019837
# 2    0.001403
# 3    0.000060
# 4    0.000009
# Name: libertylist, dtype: float64
# -------------------------------------------
#
# MORALGENLIST
# 0    0.966279
# 1    0.027271
# 2    0.005962
# 3    0.000320
# 4    0.000154
# 5    0.000009
# 6    0.000006
# Name: moralgenlist, dtype: float64
# -------------------------------------------
#
# MORALLIST
# 0    0.725783
# 1    0.202170
# 2    0.054004
# 3    0.013124
# 4    0.003614
# 5    0.000983
# 6    0.000266
# 7    0.000049
# 8    0.000006
# 9    0.000003
# Name: morallist, dtype: float64
# -------------------------------------------

# %%
from statsmodels.formula.api import ols

myfittedregression = ols(formula = 'morallist ~ length + SP + GL + PvdD + PvdA + DENK + CU + CDA + SGP + VVD + PVV  ', data = bfd).fit()
print(myfittedregression.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              morallist   R-squared:                       0.058
# Model:                            OLS   Adj. R-squared:                  0.058
# Method:                 Least Squares   F-statistic:                     1952.
# Date:                Thu, 05 Oct 2017   Prob (F-statistic):               0.00
# Time:                        13:56:25   Log-Likelihood:            -3.6272e+05
# No. Observations:              350047   AIC:                         7.255e+05
# Df Residuals:                  350035   BIC:                         7.256e+05
# Df Model:                          11
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.0370      0.004     -9.385      0.000      -0.045      -0.029
# length         0.0063   4.41e-05    143.005      0.000       0.006       0.006
# SP            -0.0156      0.005     -3.033      0.002      -0.026      -0.006
# GL             0.0737      0.005     15.833      0.000       0.065       0.083
# PvdD           0.0247      0.007      3.734      0.000       0.012       0.038
# PvdA           0.0103      0.006      1.724      0.085      -0.001       0.022
# DENK          -0.0081      0.008     -0.949      0.343      -0.025       0.009
# CU             0.1051      0.007     15.393      0.000       0.092       0.118
# CDA           -0.0140      0.004     -3.403      0.001      -0.022      -0.006
# SGP            0.0056      0.012      0.486      0.627      -0.017       0.028
# VVD            0.0382      0.004     10.433      0.000       0.031       0.045
# PVV            0.0022      0.004      0.523      0.601      -0.006       0.011
# ==============================================================================
# Omnibus:                   164780.125   Durbin-Watson:                   1.861
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          1011771.492
# Skew:                           2.219   Prob(JB):                         0.00
# Kurtosis:                      10.047   Cond. No.                         711.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
from statsmodels.formula.api import ols

myfittedregression = ols(formula = 'morallist ~ length + SP + GL + PvdD + PvdA + DENK + CU + CDA + SGP + VVD + PVV  ', data = bfd).fit()
print(myfittedregression.summary())

myfittedregression = ols(formula = 'harmlist ~ length + SP + GL + PvdD + PvdA + DENK + CU + CDA + SGP + VVD + PVV', data = bfd).fit()
print(myfittedregression.summary())

myfittedregression = ols(formula = 'fairnesslist ~ length + SP + GL + PvdD + PvdA + DENK + CU + CDA + SGP + VVD + PVV  ', data = bfd).fit()
print(myfittedregression.summary())

myfittedregression = ols(formula = 'ingrouplist ~ length + SP + GL + PvdD + PvdA + DENK + CU + CDA + SGP + VVD + PVV  ', data = bfd).fit()
print(myfittedregression.summary())

myfittedregression = ols(formula = 'authoritylist ~ length + SP + GL + PvdD + PvdA + DENK + CU + CDA + SGP + VVD + PVV ', data = bfd).fit()
print(myfittedregression.summary())

myfittedregression = ols(formula = 'puritylist ~ length + SP + GL + PvdD + PvdA + DENK + CU + CDA + SGP + VVD + PVV ', data = bfd).fit()
print(myfittedregression.summary())

myfittedregression = ols(formula = 'libertylist ~ length + SP + GL + PvdD + PvdA + DENK + CU + CDA + SGP + VVD + PVV ', data = bfd).fit()
print(myfittedregression.summary())

myfittedregression = ols(formula = 'moralgenlist ~ length + SP + GL + PvdD + PvdA + DENK + CU + CDA + SGP + VVD + PVV  ', data = bfd).fit()
print(myfittedregression.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              morallist   R-squared:                       0.058
# Model:                            OLS   Adj. R-squared:                  0.058
# Method:                 Least Squares   F-statistic:                     1952.
# Date:                Thu, 05 Oct 2017   Prob (F-statistic):               0.00
# Time:                        13:56:45   Log-Likelihood:            -3.6272e+05
# No. Observations:              350047   AIC:                         7.255e+05
# Df Residuals:                  350035   BIC:                         7.256e+05
# Df Model:                          11
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.0370      0.004     -9.385      0.000      -0.045      -0.029
# length         0.0063   4.41e-05    143.005      0.000       0.006       0.006
# SP            -0.0156      0.005     -3.033      0.002      -0.026      -0.006
# GL             0.0737      0.005     15.833      0.000       0.065       0.083
# PvdD           0.0247      0.007      3.734      0.000       0.012       0.038
# PvdA           0.0103      0.006      1.724      0.085      -0.001       0.022
# DENK          -0.0081      0.008     -0.949      0.343      -0.025       0.009
# CU             0.1051      0.007     15.393      0.000       0.092       0.118
# CDA           -0.0140      0.004     -3.403      0.001      -0.022      -0.006
# SGP            0.0056      0.012      0.486      0.627      -0.017       0.028
# VVD            0.0382      0.004     10.433      0.000       0.031       0.045
# PVV            0.0022      0.004      0.523      0.601      -0.006       0.011
# ==============================================================================
# Omnibus:                   164780.125   Durbin-Watson:                   1.861
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          1011771.492
# Skew:                           2.219   Prob(JB):                         0.00
# Kurtosis:                      10.047   Cond. No.                         711.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               harmlist   R-squared:                       0.025
# Model:                            OLS   Adj. R-squared:                  0.025
# Method:                 Least Squares   F-statistic:                     811.6
# Date:                Thu, 05 Oct 2017   Prob (F-statistic):               0.00
# Time:                        13:56:46   Log-Likelihood:            -1.4873e+05
# No. Observations:              350047   AIC:                         2.975e+05
# Df Residuals:                  350035   BIC:                         2.976e+05
# Df Model:                          11
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.0239      0.002    -11.165      0.000      -0.028      -0.020
# length         0.0021   2.39e-05     89.014      0.000       0.002       0.002
# SP            -0.0024      0.003     -0.860      0.390      -0.008       0.003
# GL             0.0356      0.003     14.092      0.000       0.031       0.041
# PvdD           0.0337      0.004      9.390      0.000       0.027       0.041
# PvdA           0.0074      0.003      2.259      0.024       0.001       0.014
# DENK          -0.0173      0.005     -3.751      0.000      -0.026      -0.008
# CU             0.0763      0.004     20.605      0.000       0.069       0.084
# CDA            0.0017      0.002      0.772      0.440      -0.003       0.006
# SGP            0.0101      0.006      1.605      0.108      -0.002       0.022
# VVD            0.0216      0.002     10.862      0.000       0.018       0.025
# PVV           -0.0005      0.002     -0.210      0.834      -0.005       0.004
# ==============================================================================
# Omnibus:                   251922.716   Durbin-Watson:                   1.881
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          3755729.129
# Skew:                           3.424   Prob(JB):                         0.00
# Kurtosis:                      17.512   Cond. No.                         711.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           fairnesslist   R-squared:                       0.007
# Model:                            OLS   Adj. R-squared:                  0.007
# Method:                 Least Squares   F-statistic:                     224.2
# Date:                Thu, 05 Oct 2017   Prob (F-statistic):               0.00
# Time:                        13:56:47   Log-Likelihood:                 11190.
# No. Observations:              350047   AIC:                        -2.236e+04
# Df Residuals:                  350035   BIC:                        -2.223e+04
# Df Model:                          11
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.0024      0.001     -1.795      0.073      -0.005       0.000
# length         0.0007   1.52e-05     48.671      0.000       0.001       0.001
# SP            -0.0049      0.002     -2.801      0.005      -0.008      -0.001
# GL            -0.0046      0.002     -2.897      0.004      -0.008      -0.002
# PvdD          -0.0090      0.002     -3.978      0.000      -0.014      -0.005
# PvdA           0.0066      0.002      3.223      0.001       0.003       0.011
# DENK          -0.0065      0.003     -2.228      0.026      -0.012      -0.001
# CU            -0.0125      0.002     -5.308      0.000      -0.017      -0.008
# CDA           -0.0059      0.001     -4.179      0.000      -0.009      -0.003
# SGP            0.0055      0.004      1.377      0.168      -0.002       0.013
# VVD           -0.0004      0.001     -0.329      0.742      -0.003       0.002
# PVV           -0.0028      0.001     -1.899      0.058      -0.006    8.98e-05
# ==============================================================================
# Omnibus:                   442009.571   Durbin-Watson:                   1.904
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):         65460156.814
# Skew:                           7.102   Prob(JB):                         0.00
# Kurtosis:                      68.470   Cond. No.                         711.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            ingrouplist   R-squared:                       0.009
# Model:                            OLS   Adj. R-squared:                  0.009
# Method:                 Least Squares   F-statistic:                     281.0
# Date:                Thu, 05 Oct 2017   Prob (F-statistic):               0.00
# Time:                        13:56:48   Log-Likelihood:            -2.2197e+05
# No. Observations:              350047   AIC:                         4.440e+05
# Df Residuals:                  350035   BIC:                         4.441e+05
# Df Model:                          11
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.0042      0.003      1.602      0.109      -0.001       0.009
# length         0.0015   2.95e-05     52.459      0.000       0.001       0.002
# SP             0.0003      0.003      0.095      0.925      -0.006       0.007
# GL             0.0260      0.003      8.344      0.000       0.020       0.032
# PvdD          -0.0057      0.004     -1.290      0.197      -0.014       0.003
# PvdA          -0.0059      0.004     -1.474      0.140      -0.014       0.002
# DENK           0.0335      0.006      5.905      0.000       0.022       0.045
# CU             0.0286      0.005      6.254      0.000       0.020       0.038
# CDA           -0.0171      0.003     -6.213      0.000      -0.023      -0.012
# SGP            0.0258      0.008      3.314      0.001       0.011       0.041
# VVD            0.0083      0.002      3.388      0.001       0.003       0.013
# PVV            0.0060      0.003      2.094      0.036       0.000       0.012
# ==============================================================================
# Omnibus:                   323593.598   Durbin-Watson:                   1.921
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          9742231.517
# Skew:                           4.664   Prob(JB):                         0.00
# Kurtosis:                      27.103   Cond. No.                         711.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          authoritylist   R-squared:                       0.012
# Model:                            OLS   Adj. R-squared:                  0.012
# Method:                 Least Squares   F-statistic:                     393.4
# Date:                Thu, 05 Oct 2017   Prob (F-statistic):               0.00
# Time:                        13:56:48   Log-Likelihood:                -80197.
# No. Observations:              350047   AIC:                         1.604e+05
# Df Residuals:                  350035   BIC:                         1.605e+05
# Df Model:                          11
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.0035      0.002     -2.003      0.045      -0.007   -7.63e-05
# length         0.0013   1.97e-05     64.923      0.000       0.001       0.001
# SP            -0.0088      0.002     -3.845      0.000      -0.013      -0.004
# GL             0.0037      0.002      1.782      0.075      -0.000       0.008
# PvdD           0.0075      0.003      2.543      0.011       0.002       0.013
# PvdA           0.0078      0.003      2.934      0.003       0.003       0.013
# DENK           0.0105      0.004      2.766      0.006       0.003       0.018
# CU             0.0103      0.003      3.367      0.001       0.004       0.016
# CDA           -0.0032      0.002     -1.748      0.080      -0.007       0.000
# SGP            0.0037      0.005      0.709      0.478      -0.006       0.014
# VVD            0.0020      0.002      1.195      0.232      -0.001       0.005
# PVV            0.0018      0.002      0.949      0.343      -0.002       0.006
# ==============================================================================
# Omnibus:                   327324.912   Durbin-Watson:                   1.928
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):         12480236.935
# Skew:                           4.636   Prob(JB):                         0.00
# Kurtosis:                      30.743   Cond. No.                         711.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             puritylist   R-squared:                       0.005
# Model:                            OLS   Adj. R-squared:                  0.005
# Method:                 Least Squares   F-statistic:                     172.8
# Date:                Thu, 05 Oct 2017   Prob (F-statistic):               0.00
# Time:                        13:56:49   Log-Likelihood:             1.1992e+05
# No. Observations:              350047   AIC:                        -2.398e+05
# Df Residuals:                  350035   BIC:                        -2.397e+05
# Df Model:                          11
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.0022      0.001     -2.208      0.027      -0.004      -0.000
# length         0.0005   1.11e-05     42.091      0.000       0.000       0.000
# SP            -0.0012      0.001     -0.935      0.350      -0.004       0.001
# GL             0.0013      0.001      1.071      0.284      -0.001       0.004
# PvdD           0.0038      0.002      2.286      0.022       0.001       0.007
# PvdA          -0.0035      0.002     -2.320      0.020      -0.006      -0.001
# DENK          -0.0085      0.002     -3.962      0.000      -0.013      -0.004
# CU             0.0110      0.002      6.381      0.000       0.008       0.014
# CDA           -0.0012      0.001     -1.191      0.234      -0.003       0.001
# SGP           -0.0052      0.003     -1.765      0.078      -0.011       0.001
# VVD           -0.0001      0.001     -0.158      0.874      -0.002       0.002
# PVV           -0.0017      0.001     -1.588      0.112      -0.004       0.000
# ==============================================================================
# Omnibus:                   443047.114   Durbin-Watson:                   1.861
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):         58130769.075
# Skew:                           7.197   Prob(JB):                         0.00
# Kurtosis:                      64.469   Cond. No.                         711.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            libertylist   R-squared:                       0.006
# Model:                            OLS   Adj. R-squared:                  0.006
# Method:                 Least Squares   F-statistic:                     203.1
# Date:                Thu, 05 Oct 2017   Prob (F-statistic):               0.00
# Time:                        13:56:50   Log-Likelihood:             1.4589e+05
# No. Observations:              350047   AIC:                        -2.918e+05
# Df Residuals:                  350035   BIC:                        -2.916e+05
# Df Model:                          11
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.0068      0.001     -7.371      0.000      -0.009      -0.005
# length         0.0005   1.03e-05     46.668      0.000       0.000       0.001
# SP             0.0050      0.001      4.196      0.000       0.003       0.007
# GL             0.0005      0.001      0.480      0.631      -0.002       0.003
# PvdD          -0.0050      0.002     -3.258      0.001      -0.008      -0.002
# PvdA          -0.0027      0.001     -1.933      0.053      -0.005    3.75e-05
# DENK          -0.0003      0.002     -0.128      0.898      -0.004       0.004
# CU             0.0003      0.002      0.185      0.853      -0.003       0.003
# CDA            0.0002      0.001      0.191      0.848      -0.002       0.002
# SGP           -0.0063      0.003     -2.320      0.020      -0.012      -0.001
# VVD            0.0005      0.001      0.583      0.560      -0.001       0.002
# PVV           -0.0021      0.001     -2.094      0.036      -0.004      -0.000
# ==============================================================================
# Omnibus:                   458475.782   Durbin-Watson:                   1.894
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):         69245459.774
# Skew:                           7.617   Prob(JB):                         0.00
# Kurtosis:                      70.198   Cond. No.                         711.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           moralgenlist   R-squared:                       0.005
# Model:                            OLS   Adj. R-squared:                  0.005
# Method:                 Least Squares   F-statistic:                     158.6
# Date:                Thu, 05 Oct 2017   Prob (F-statistic):               0.00
# Time:                        13:56:51   Log-Likelihood:                 11124.
# No. Observations:              350047   AIC:                        -2.222e+04
# Df Residuals:                  350035   BIC:                        -2.210e+04
# Df Model:                          11
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.0013      0.001     -0.950      0.342      -0.004       0.001
# length         0.0006   1.52e-05     41.155      0.000       0.001       0.001
# SP            -0.0010      0.002     -0.592      0.554      -0.004       0.002
# GL             0.0036      0.002      2.248      0.025       0.000       0.007
# PvdD           0.0082      0.002      3.593      0.000       0.004       0.013
# PvdA           0.0066      0.002      3.206      0.001       0.003       0.011
# DENK           0.0018      0.003      0.629      0.529      -0.004       0.008
# CU             0.0018      0.002      0.767      0.443      -0.003       0.006
# CDA            0.0079      0.001      5.571      0.000       0.005       0.011
# SGP           -0.0064      0.004     -1.592      0.111      -0.014       0.001
# VVD            0.0046      0.001      3.677      0.000       0.002       0.007
# PVV            0.0033      0.001      2.203      0.028       0.000       0.006
# ==============================================================================
# Omnibus:                   429395.601   Durbin-Watson:                   1.920
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):         51360616.684
# Skew:                           6.823   Prob(JB):                         0.00
# Kurtosis:                      60.751   Cond. No.                         711.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
bfd['moralratio'] = bfd['morallist']/bfd['length']
bfd['harmratio'] = bfd['harmlist']/bfd['length']
bfd['fairnessratio'] = bfd['fairnesslist']/bfd['length']
bfd['ingroupratio'] = bfd['ingrouplist']/bfd['length']
bfd['authorityratio'] = bfd['authoritylist']/bfd['length']
bfd['purityratio'] = bfd['puritylist']/bfd['length']
bfd['libertyratio'] = bfd['libertylist']/bfd['length']
bfd['moralgenratio'] = bfd['moralgenlist']/bfd['length']

# %%
myfittedregression = ols(formula = 'moralratio ~ SP + GL + PvdD + PvdA + DENK + CU + CDA + SGP + VVD + PVV  ', data = bfd).fit()
print(myfittedregression.summary())

myfittedregression = ols(formula = 'harmratio ~ SP + GL + PvdD + PvdA + DENK + CU + CDA + SGP + VVD + PVV  ', data = bfd).fit()
print(myfittedregression.summary())

myfittedregression = ols(formula = 'fairnessratio ~ SP + GL + PvdD + PvdA + DENK + CU + CDA + SGP + VVD + PVV   ', data = bfd).fit()
print(myfittedregression.summary())

myfittedregression = ols(formula = 'ingroupratio ~ SP + GL + PvdD + PvdA + DENK + CU + CDA + SGP + VVD + PVV  ', data = bfd).fit()
print(myfittedregression.summary())

myfittedregression = ols(formula = 'authorityratio ~ SP + GL + PvdD + PvdA + DENK + CU + CDA + SGP + VVD + PVV   ', data = bfd).fit()
print(myfittedregression.summary())

myfittedregression = ols(formula = 'purityratio ~   SP + GL + PvdD + PvdA + DENK + CU + CDA + SGP + VVD + PVV  ', data = bfd).fit()
print(myfittedregression.summary())

myfittedregression = ols(formula = 'libertyratio ~   SP + GL + PvdD + PvdA + DENK + CU + CDA + SGP + VVD + PVV   ', data = bfd).fit()
print(myfittedregression.summary())

myfittedregression = ols(formula = 'moralgenratio ~   SP + GL + PvdD + PvdA + DENK + CU + CDA + SGP + VVD + PVV  ', data = bfd).fit()
print(myfittedregression.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             moralratio   R-squared:                       0.002
# Model:                            OLS   Adj. R-squared:                  0.002
# Method:                 Least Squares   F-statistic:                     54.85
# Date:                Thu, 05 Oct 2017   Prob (F-statistic):          2.35e-111
# Time:                        15:19:04   Log-Likelihood:             1.0332e+06
# No. Observations:              349829   AIC:                        -2.066e+06
# Df Residuals:                  349818   BIC:                        -2.066e+06
# Df Model:                          10
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.0057   5.21e-05    108.703      0.000       0.006       0.006
# SP            -0.0002   9.49e-05     -2.512      0.012      -0.000   -5.24e-05
# GL             0.0011   8.62e-05     13.290      0.000       0.001       0.001
# PvdD           0.0003      0.000      2.648      0.008    8.42e-05       0.001
# PvdA           0.0001      0.000      1.025      0.305      -0.000       0.000
# DENK          -0.0002      0.000     -1.559      0.119      -0.001     6.3e-05
# CU             0.0017      0.000     13.104      0.000       0.001       0.002
# CDA           -0.0003   7.63e-05     -4.061      0.000      -0.000      -0.000
# SGP            0.0005      0.000      2.311      0.021    7.54e-05       0.001
# VVD            0.0005   6.78e-05      7.781      0.000       0.000       0.001
# PVV         3.978e-05   7.95e-05      0.500      0.617      -0.000       0.000
# ==============================================================================
# Omnibus:                   376010.012   Durbin-Watson:                   1.885
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):        101875427.614
# Skew:                           4.996   Prob(JB):                         0.00
# Kurtosis:                      86.002   Cond. No.                         11.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              harmratio   R-squared:                       0.002
# Model:                            OLS   Adj. R-squared:                  0.002
# Method:                 Least Squares   F-statistic:                     58.39
# Date:                Thu, 05 Oct 2017   Prob (F-statistic):          6.25e-119
# Time:                        15:19:06   Log-Likelihood:             1.2531e+06
# No. Observations:              349829   AIC:                        -2.506e+06
# Df Residuals:                  349818   BIC:                        -2.506e+06
# Df Model:                          10
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.0017   2.78e-05     62.941      0.000       0.002       0.002
# SP         -5.616e-05   5.06e-05     -1.109      0.267      -0.000    4.31e-05
# GL             0.0005    4.6e-05     10.983      0.000       0.000       0.001
# PvdD           0.0004   6.53e-05      6.430      0.000       0.000       0.001
# PvdA        4.283e-05   5.92e-05      0.724      0.469   -7.32e-05       0.000
# DENK          -0.0003   8.37e-05     -4.040      0.000      -0.001      -0.000
# CU             0.0011   6.74e-05     16.521      0.000       0.001       0.001
# CDA        -4.185e-05   4.07e-05     -1.028      0.304      -0.000    3.79e-05
# SGP            0.0004      0.000      3.202      0.001       0.000       0.001
# VVD            0.0003   3.62e-05      8.007      0.000       0.000       0.000
# PVV        -6.797e-05   4.24e-05     -1.603      0.109      -0.000    1.51e-05
# ==============================================================================
# Omnibus:                   443184.935   Durbin-Watson:                   1.885
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):        174316117.186
# Skew:                           6.690   Prob(JB):                         0.00
# Kurtosis:                     111.535   Cond. No.                         11.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          fairnessratio   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                  0.000
# Method:                 Least Squares   F-statistic:                     7.505
# Date:                Thu, 05 Oct 2017   Prob (F-statistic):           4.67e-12
# Time:                        15:19:07   Log-Likelihood:             1.4111e+06
# No. Observations:              349829   AIC:                        -2.822e+06
# Df Residuals:                  349818   BIC:                        -2.822e+06
# Df Model:                          10
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.0007   1.77e-05     37.250      0.000       0.001       0.001
# SP         -6.681e-05   3.22e-05     -2.073      0.038      -0.000   -3.63e-06
# GL         -4.048e-05   2.93e-05     -1.383      0.167   -9.78e-05    1.69e-05
# PvdD          -0.0001   4.16e-05     -3.116      0.002      -0.000   -4.81e-05
# PvdA           0.0001   3.77e-05      2.669      0.008    2.67e-05       0.000
# DENK          -0.0001   5.33e-05     -2.564      0.010      -0.000   -3.22e-05
# CU            -0.0002   4.29e-05     -4.494      0.000      -0.000      -0.000
# CDA        -9.431e-05   2.59e-05     -3.639      0.000      -0.000   -4.35e-05
# SGP         7.344e-05    7.3e-05      1.005      0.315   -6.97e-05       0.000
# VVD         2.042e-05    2.3e-05      0.887      0.375   -2.47e-05    6.55e-05
# PVV        -1.397e-05    2.7e-05     -0.518      0.605   -6.69e-05    3.89e-05
# ==============================================================================
# Omnibus:                   864630.985   Durbin-Watson:                   1.930
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):     123867780463.640
# Skew:                          25.604   Prob(JB):                         0.00
# Kurtosis:                    2917.673   Cond. No.                         11.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           ingroupratio   R-squared:                       0.001
# Model:                            OLS   Adj. R-squared:                  0.001
# Method:                 Least Squares   F-statistic:                     22.92
# Date:                Thu, 05 Oct 2017   Prob (F-statistic):           1.33e-43
# Time:                        15:19:08   Log-Likelihood:             1.1444e+06
# No. Observations:              349829   AIC:                        -2.289e+06
# Df Residuals:                  349818   BIC:                        -2.289e+06
# Df Model:                          10
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.0017   3.79e-05     43.934      0.000       0.002       0.002
# SP          -3.89e-05   6.91e-05     -0.563      0.573      -0.000    9.65e-05
# GL             0.0003   6.27e-05      5.418      0.000       0.000       0.000
# PvdD       -8.756e-05   8.91e-05     -0.982      0.326      -0.000    8.71e-05
# PvdA       -4.537e-05   8.08e-05     -0.562      0.574      -0.000       0.000
# DENK           0.0006      0.000      5.276      0.000       0.000       0.001
# CU             0.0007   9.19e-05      7.189      0.000       0.000       0.001
# CDA           -0.0003   5.55e-05     -5.713      0.000      -0.000      -0.000
# SGP            0.0008      0.000      5.102      0.000       0.000       0.001
# VVD         6.614e-05   4.93e-05      1.340      0.180   -3.06e-05       0.000
# PVV         9.253e-05   5.79e-05      1.599      0.110   -2.09e-05       0.000
# ==============================================================================
# Omnibus:                   666745.964   Durbin-Watson:                   1.933
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):       4503915968.257
# Skew:                          14.295   Prob(JB):                         0.00
# Kurtosis:                     558.134   Cond. No.                         11.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         authorityratio   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                  0.000
# Method:                 Least Squares   F-statistic:                     6.665
# Date:                Thu, 05 Oct 2017   Prob (F-statistic):           1.96e-10
# Time:                        15:19:10   Log-Likelihood:             1.3131e+06
# No. Observations:              349829   AIC:                        -2.626e+06
# Df Residuals:                  349818   BIC:                        -2.626e+06
# Df Model:                          10
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.0012   2.34e-05     51.607      0.000       0.001       0.001
# SP            -0.0002   4.27e-05     -3.918      0.000      -0.000   -8.35e-05
# GL          3.543e-05   3.87e-05      0.915      0.360   -4.05e-05       0.000
# PvdD           0.0002    5.5e-05      3.468      0.001     8.3e-05       0.000
# PvdA           0.0001   4.99e-05      2.201      0.028     1.2e-05       0.000
# DENK           0.0002   7.05e-05      2.610      0.009    4.59e-05       0.000
# CU          9.332e-05   5.67e-05      1.645      0.100   -1.79e-05       0.000
# CDA        -6.709e-05   3.43e-05     -1.956      0.050      -0.000    1.26e-07
# SGP            0.0001   9.66e-05      1.294      0.196   -6.44e-05       0.000
# VVD         1.702e-05   3.05e-05      0.559      0.576   -4.27e-05    7.67e-05
# PVV         5.169e-05   3.57e-05      1.447      0.148   -1.83e-05       0.000
# ==============================================================================
# Omnibus:                   580994.321   Durbin-Watson:                   1.942
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):       1339785552.276
# Skew:                          10.819   Prob(JB):                         0.00
# Kurtosis:                     305.403   Cond. No.                         11.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            purityratio   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                  0.000
# Method:                 Least Squares   F-statistic:                     5.447
# Date:                Thu, 05 Oct 2017   Prob (F-statistic):           3.98e-08
# Time:                        15:19:12   Log-Likelihood:             1.5138e+06
# No. Observations:              349829   AIC:                        -3.027e+06
# Df Residuals:                  349818   BIC:                        -3.027e+06
# Df Model:                          10
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.0004   1.32e-05     32.578      0.000       0.000       0.000
# SP           7.38e-06    2.4e-05      0.307      0.759   -3.97e-05    5.45e-05
# GL          2.774e-05   2.18e-05      1.271      0.204    -1.5e-05    7.05e-05
# PvdD        3.375e-05    3.1e-05      1.088      0.276    -2.7e-05    9.45e-05
# PvdA       -3.746e-05   2.81e-05     -1.333      0.183   -9.25e-05    1.76e-05
# DENK          -0.0002   3.98e-05     -4.344      0.000      -0.000   -9.48e-05
# CU             0.0001    3.2e-05      3.698      0.000    5.56e-05       0.000
# CDA        -3.225e-05   1.93e-05     -1.669      0.095   -7.01e-05    5.63e-06
# SGP           -0.0001   5.45e-05     -1.949      0.051      -0.000    5.74e-07
# VVD        -1.655e-05   1.72e-05     -0.964      0.335   -5.02e-05    1.71e-05
# PVV         -2.04e-05   2.01e-05     -1.013      0.311   -5.98e-05    1.91e-05
# ==============================================================================
# Omnibus:                   654400.959   Durbin-Watson:                   1.896
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):       1993437109.465
# Skew:                          14.060   Prob(JB):                         0.00
# Kurtosis:                     371.740   Cond. No.                         11.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           libertyratio   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                  0.000
# Method:                 Least Squares   F-statistic:                     6.826
# Date:                Thu, 05 Oct 2017   Prob (F-statistic):           9.63e-11
# Time:                        15:19:14   Log-Likelihood:             1.5821e+06
# No. Observations:              349829   AIC:                        -3.164e+06
# Df Residuals:                  349818   BIC:                        -3.164e+06
# Df Model:                          10
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.0003   1.08e-05     30.744      0.000       0.000       0.000
# SP             0.0001   1.98e-05      5.176      0.000    6.36e-05       0.000
# GL          2.548e-05    1.8e-05      1.419      0.156   -9.71e-06    6.07e-05
# PvdD         -7.2e-05   2.55e-05     -2.823      0.005      -0.000    -2.2e-05
# PvdA       -3.883e-05   2.31e-05     -1.680      0.093   -8.41e-05    6.46e-06
# DENK       -4.963e-06   3.27e-05     -0.152      0.879   -6.91e-05    5.91e-05
# CU          4.911e-05   2.63e-05      1.867      0.062   -2.45e-06       0.000
# CDA         2.338e-06   1.59e-05      0.147      0.883   -2.88e-05    3.35e-05
# SGP           -0.0001   4.48e-05     -2.448      0.014      -0.000   -2.19e-05
# VVD         8.871e-06   1.41e-05      0.628      0.530   -1.88e-05    3.65e-05
# PVV        -2.278e-05   1.66e-05     -1.376      0.169   -5.52e-05    9.67e-06
# ==============================================================================
# Omnibus:                   614715.647   Durbin-Watson:                   1.884
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):       1276089047.713
# Skew:                          12.347   Prob(JB):                         0.00
# Kurtosis:                     297.850   Cond. No.                         11.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          moralgenratio   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                  0.000
# Method:                 Least Squares   F-statistic:                     4.514
# Date:                Thu, 05 Oct 2017   Prob (F-statistic):           2.05e-06
# Time:                        15:19:15   Log-Likelihood:             1.3682e+06
# No. Observations:              349829   AIC:                        -2.736e+06
# Df Residuals:                  349818   BIC:                        -2.736e+06
# Df Model:                          10
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.0006      2e-05     30.973      0.000       0.001       0.001
# SP          -2.16e-05   3.64e-05     -0.593      0.553    -9.3e-05    4.98e-05
# GL             0.0001   3.31e-05      3.531      0.000     5.2e-05       0.000
# PvdD           0.0001    4.7e-05      2.303      0.021    1.61e-05       0.000
# PvdA        8.773e-05   4.26e-05      2.059      0.039    4.24e-06       0.000
# DENK       -2.087e-05   6.03e-05     -0.346      0.729      -0.000    9.73e-05
# CU          8.653e-06   4.85e-05      0.178      0.858   -8.64e-05       0.000
# CDA            0.0001   2.93e-05      4.400      0.000    7.15e-05       0.000
# SGP           -0.0002   8.26e-05     -1.941      0.052      -0.000    1.57e-06
# VVD         7.425e-05    2.6e-05      2.853      0.004    2.32e-05       0.000
# PVV         4.333e-05   3.05e-05      1.420      0.156   -1.65e-05       0.000
# ==============================================================================
# Omnibus:                   745108.518   Durbin-Watson:                   1.930
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):       7090222067.489
# Skew:                          18.539   Prob(JB):                         0.00
# Kurtosis:                     699.455   Cond. No.                         11.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
bfd['moraldummy'] = np.where(bfd['morallist']>0, '1', '0')
bfd['harmdummy'] = np.where(bfd['harmlist']>0, '1', '0')
bfd['fairnessdummy'] = np.where(bfd['fairnesslist']>0, '1', '0')
bfd['ingroupdummy'] = np.where(bfd['ingrouplist']>0, '1', '0')
bfd['authoritydummy'] = np.where(bfd['authoritylist']>0, '1', '0')
bfd['puritydummy'] = np.where(bfd['puritylist']>0, '1', '0')
bfd['libertydummy'] = np.where(bfd['libertylist']>0, '1', '0')
bfd['moralgendummy'] = np.where(bfd['moralgenlist']>0, '1', '0')

# %%
bfd.to_csv('/home/linda/manifestos/combined data/Dutch tweets.csv')
bfd.to_csv('/home/linda/myrealcomputer/Dutch tweets.csv')
